# %% [markdown]
# <a href="https://colab.research.google.com/github/EternalSorrrow/transformer-feedforward-kernel/blob/main/bpe_classification_setup_lka_var.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Nov  3 13:08:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    42W / 350W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/google-research/long-range-arena.git
# Out:
# Cloning into 'long-range-arena'...
# remote: Enumerating objects: 474, done.
# remote: Counting objects: 100% (474/474), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 474 (delta 330), reused 418 (delta 278), pack-reused 0
# Receiving objects: 100% (474/474), 153.25 KiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (330/330), done.

# %%
#Execute if A100 is the current GPU

# !pip3 install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio==0.9.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.9.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torch-1.9.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (2041.3 MB)
#      |█████████████                   | 834.1 MB 1.2 MB/s eta 0:16:33tcmalloc: large alloc 1147494400 bytes == 0x55740910a000 @  0x7f0013ab2615 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf717d00 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf6a6039 0x5573cf6e9409 0x5573cf6a4c52 0x5573cf717c25 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713915 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee
#      |████████████████▌               | 1055.7 MB 1.2 MB/s eta 0:13:59tcmalloc: large alloc 1434370048 bytes == 0x55744d760000 @  0x7f0013ab2615 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf717d00 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf6a6039 0x5573cf6e9409 0x5573cf6a4c52 0x5573cf717c25 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713915 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee
#      |█████████████████████           | 1336.2 MB 1.2 MB/s eta 0:09:57tcmalloc: large alloc 1792966656 bytes == 0x5573d2592000 @  0x7f0013ab2615 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf717d00 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf6a6039 0x5573cf6e9409 0x5573cf6a4c52 0x5573cf717c25 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713915 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee
#      |██████████████████████████▌     | 1691.1 MB 1.2 MB/s eta 0:05:00tcmalloc: large alloc 2241208320 bytes == 0x55743d37a000 @  0x7f0013ab2615 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf717d00 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf796c66 0x5573cf713daf 0x5573cf6a6039 0x5573cf6e9409 0x5573cf6a4c52 0x5573cf717c25 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713915 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee
#      |████████████████████████████████| 2041.3 MB 1.1 MB/s eta 0:00:01tcmalloc: large alloc 2041315328 bytes == 0x5574c2cdc000 @  0x7f0013ab11e7 0x5573cf6d7067 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee
# tcmalloc: large alloc 2551644160 bytes == 0x55753c79c000 @  0x7f0013ab2615 0x5573cf6a14cc 0x5573cf78147a 0x5573cf6a42ed 0x5573cf795e1d 0x5573cf717e99 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf713c0d 0x5573cf6a5afa 0x5573cf713c0d 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a5bda 0x5573cf714737 0x5573cf7129ee 0x5573cf6a6271
#      |████████████████████████████████| 2041.3 MB 5.2 kB/s
# Collecting torchvision==0.10.1+cu111
#   Downloading https://download.pytorch.org/whl/cu111/torchvision-0.10.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 1.2 MB/s
# Collecting torchaudio==0.9.1
#   Downloading torchaudio-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 2.6 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.1+cu111) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.1+cu111) (1.19.5)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.1+cu111) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu111
#     Uninstalling torchvision-0.10.0+cu111:
#       Successfully uninstalled torchvision-0.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.9.1+cu111 which is incompatible.
# Successfully installed torch-1.9.1+cu111 torchaudio-0.9.1 torchvision-0.10.1+cu111

# %%
# %cd /content/long-range-arena

import torch
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

from lra_benchmarks.text_classification.input_pipeline import get_tc_datasets

batch_size=16
accumulation_steps=32 // batch_size
max_length=4000

train_dataset, valid_dataset, test_dataset, encoder = get_tc_datasets(1, 'imdb_reviews', batch_size=batch_size, max_length=max_length)
# Out:
# /content/long-range-arena
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBB222J/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBB222J/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteBB222J/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# INFO:tensorflow:Finished preprocessing
# INFO:tensorflow:Finished preprocessing
# INFO:tensorflow:<MapDataset shapes: {Source: (), Target: ()}, types: {Source: tf.string, Target: tf.int64}>
# INFO:tensorflow:<MapDataset shapes: {Source: (), Target: ()}, types: {Source: tf.string, Target: tf.int64}>

# %%
v_sample = next(iter(valid_dataset))['inputs']
t_sample = next(iter(test_dataset))['inputs']

for i in range(min(4, batch_size)):
  print(encoder.decode(v_sample[i]))

print()

for i in range(min(4, batch_size)):
  print(encoder.decode(t_sample[i]))
# Out:
# There are films that make careers. For George Romero, it was NIGHT OF THE LIVING DEAD; for Kevin Smith, CLERKS; for Robert Rodriguez, EL MARIACHI. Add to that list Onur Tukel's absolutely amazing DING-A-LING-LESS. Flawless film-making, and as assured and as professional as any of the aforementioned movies. I haven't laughed this hard since I saw THE FULL MONTY. (And, even then, I don't think I laughed quite this hard... So to speak.) Tukel's talent is considerable: DING-A-LING-LESS is so chock full of double entendres that one would have to sit down with a copy of this script and do a line-by-line examination of it to fully appreciate the, uh, breadth and width of it. Every shot is beautifully composed (a clear sign of a sure-handed director), and the performances all around are solid (there's none of the over-the-top scenery chewing one might've expected from a film like this). DING-A-LING-LESS is a film whose time has come.
# A blackly comic tale of a down-trodden priest, Nazarin showcases the economy that Luis Bunuel was able to achieve in being able to tell a deeply humanist fable with a minimum of fuss. As an output from his Mexican era of film making, it was an invaluable talent to possess, with little money and extremely tight schedules. Nazarin, however, surpasses many of Bunuel's previous Mexican films in terms of the acting (Francisco Rabal is excellent), narrative and theme.<br /><br />The theme, interestingly, is something that was explored again in Viridiana, made three years later in Spain. It concerns the individual's struggle for humanity and altruism amongst a society that rejects any notion of virtue. Father Nazarin, however, is portrayed more sympathetically than Sister Viridiana. Whereas the latter seems to choose charity because she wishes to atone for her (perceived) sins, Nazarin's whole existence and reason for being seems to be to help others, whether they (or we) like it or not. The film's last scenes, in which he casts doubt on his behaviour and, in a split second, has to choose between the life he has been leading or the conventional life that is expected of a priest, are so emotional because they concern his moral integrity and we are never quite sure whether it remains intact or not.<br /><br />This is a remarkable film and I would urge anyone interested in classic cinema to seek it out. It is one of Bunuel's most moving films, and encapsulates many of his obsessions: frustrated desire, mad love, religious hypocrisy etc. In my view 'Nazarin' is second only to 'The Exterminating Angel', in terms of his Mexican movies, and is certainly near the top of the list of Bunuel's total filmic output.
# Scary Movie 1-4, Epic Movie, Date Movie, Meet the Spartans, Not another Teen Movie and Another Gay Movie. Making "Superhero Movie" the eleventh in a series that single handily ruined the parody genre. Now I'll admit it I have a soft spot for classics such as Airplane and The Naked Gun but you know you've milked a franchise so bad when you can see the gags a mile off. In fact the only thing that might really temp you into going to see this disaster is the incredibly funny but massive sell-out Leslie Neilson.<br /><br />You can tell he needs the money, wither that or he intends to go down with the ship like a good Capitan would. In no way is he bringing down this genre but hell he's not helping it. But if I feel sorry for anybody in this film its decent actor Drake Bell who is put through an immense amount of embarrassment. The people who are put through the largest amount of torture by far however is the audience forced to sit through 90 minutes of laughless bile no funnier than herpes.<br /><br />After spoofing disaster films in Airplane!, police shows in The Naked Gun, and Hollywood horrors in Scary Movie 3 and 4, producer David Zucker sets his satirical sights on the superhero genre with this anarchic comedy lampooning everything from Spider-Man to X-Men and Superman Returns.<br /><br />Shortly after being bitten by a genetically altered dragonfly, high-school outcast Rick Riker (Drake Bell) begins to experience a startling transformation. Now Rick's skin is as strong as steel, and he possesses the strength of ten men. Determined to use his newfound powers to fight crime, Rick creates a special costume and assumes the identity of The Dragonfly -- a fearless crime fighter dedicated to keeping the streets safe for law-abiding citizens.<br /><br />But every superhero needs a nemesis, and after Lou Landers (Christopher McDonald) is caught in the middle of an experiment gone horribly awry, he develops the power to leech the life force out of anyone he meets and becomes the villainous Hourglass. Intent on achieving immortality, the Hourglass attempts to gather as much life force as possible as the noble Dragonfly sets out to take down his archenemy and realize his destiny as a true hero. Craig Mazin writes and directs this low-flying spoof.<br /><br />featuring Tracy Morgan, Pamela Anderson, Leslie Nielsen, Marion Ross, Jeffrey Tambor, and Regina Hall.<br /><br />Hell Superhero Movie may earn some merit in the fact that it's a hell of a lot better than Meet the Spartans and Epic Movie. But with great responsibility comes one of the worst outings of 2008 to date. Laughless but a little less irritating than Meet the Spartans. And in the same sense much more forgettable than meet the Spartans. But maybe that's a good reason. There are still some of us trying to scrape away the stain that was Meet the Spartans from our memory.<br /><br />My final verdict? Avoid, unless you're one of thoses people who enjoy such car crash cinema. As bad as Date Movie and Scary Movie 2 but not quite as bad as Meet the Spartans or Epic Movie. Super Villain.
# Poor Shirley MacLaine tries hard to lend some gravitas to this mawkish, gag-inducing "feel-good" movie, but she's trampled by the run-away sentimentality of a film that's not the least bit grounded in reality.<br /><br />This was directed by Curtis Hanson? Did he have a lobotomy since we last heard from him? Hanson can do effective drama sprinkled with comedy, as evidenced by "Wonder Boys." So I don't know what happened to him here. This is the kind of movie that doesn't want to accept that life is messy and fussy, and that neat, tidy endings (however implausible they might be) might make for a nice closing shot, but come across as utterly phony if the people watching the film have been through anything remotely like what the characters in the film go through.<br /><br />My wife and I made a game of calling out the plot points before they occurred -- e.g. "the old man's going to teach her to read and then drop dead." Bingo! This is one of those movies where the characters give little speeches summarizing their emotional problems, making you wonder why they still have emotional problems if they're that aware of what's causing them. Toni Collette (a fine actress, by the way, and one of my favorites if not given a lot to work with here), gives a speech early on about why she buys so many shoes and never wears them, spelling out in flashing neon the film's awkward connecting motif. At that moment, I knew what I was in for, and the film was a downward spiral from there.<br /><br />Grade: C-
#
# There are films that make careers. For George Romero, it was NIGHT OF THE LIVING DEAD; for Kevin Smith, CLERKS; for Robert Rodriguez, EL MARIACHI. Add to that list Onur Tukel's absolutely amazing DING-A-LING-LESS. Flawless film-making, and as assured and as professional as any of the aforementioned movies. I haven't laughed this hard since I saw THE FULL MONTY. (And, even then, I don't think I laughed quite this hard... So to speak.) Tukel's talent is considerable: DING-A-LING-LESS is so chock full of double entendres that one would have to sit down with a copy of this script and do a line-by-line examination of it to fully appreciate the, uh, breadth and width of it. Every shot is beautifully composed (a clear sign of a sure-handed director), and the performances all around are solid (there's none of the over-the-top scenery chewing one might've expected from a film like this). DING-A-LING-LESS is a film whose time has come.
# A blackly comic tale of a down-trodden priest, Nazarin showcases the economy that Luis Bunuel was able to achieve in being able to tell a deeply humanist fable with a minimum of fuss. As an output from his Mexican era of film making, it was an invaluable talent to possess, with little money and extremely tight schedules. Nazarin, however, surpasses many of Bunuel's previous Mexican films in terms of the acting (Francisco Rabal is excellent), narrative and theme.<br /><br />The theme, interestingly, is something that was explored again in Viridiana, made three years later in Spain. It concerns the individual's struggle for humanity and altruism amongst a society that rejects any notion of virtue. Father Nazarin, however, is portrayed more sympathetically than Sister Viridiana. Whereas the latter seems to choose charity because she wishes to atone for her (perceived) sins, Nazarin's whole existence and reason for being seems to be to help others, whether they (or we) like it or not. The film's last scenes, in which he casts doubt on his behaviour and, in a split second, has to choose between the life he has been leading or the conventional life that is expected of a priest, are so emotional because they concern his moral integrity and we are never quite sure whether it remains intact or not.<br /><br />This is a remarkable film and I would urge anyone interested in classic cinema to seek it out. It is one of Bunuel's most moving films, and encapsulates many of his obsessions: frustrated desire, mad love, religious hypocrisy etc. In my view 'Nazarin' is second only to 'The Exterminating Angel', in terms of his Mexican movies, and is certainly near the top of the list of Bunuel's total filmic output.
# Scary Movie 1-4, Epic Movie, Date Movie, Meet the Spartans, Not another Teen Movie and Another Gay Movie. Making "Superhero Movie" the eleventh in a series that single handily ruined the parody genre. Now I'll admit it I have a soft spot for classics such as Airplane and The Naked Gun but you know you've milked a franchise so bad when you can see the gags a mile off. In fact the only thing that might really temp you into going to see this disaster is the incredibly funny but massive sell-out Leslie Neilson.<br /><br />You can tell he needs the money, wither that or he intends to go down with the ship like a good Capitan would. In no way is he bringing down this genre but hell he's not helping it. But if I feel sorry for anybody in this film its decent actor Drake Bell who is put through an immense amount of embarrassment. The people who are put through the largest amount of torture by far however is the audience forced to sit through 90 minutes of laughless bile no funnier than herpes.<br /><br />After spoofing disaster films in Airplane!, police shows in The Naked Gun, and Hollywood horrors in Scary Movie 3 and 4, producer David Zucker sets his satirical sights on the superhero genre with this anarchic comedy lampooning everything from Spider-Man to X-Men and Superman Returns.<br /><br />Shortly after being bitten by a genetically altered dragonfly, high-school outcast Rick Riker (Drake Bell) begins to experience a startling transformation. Now Rick's skin is as strong as steel, and he possesses the strength of ten men. Determined to use his newfound powers to fight crime, Rick creates a special costume and assumes the identity of The Dragonfly -- a fearless crime fighter dedicated to keeping the streets safe for law-abiding citizens.<br /><br />But every superhero needs a nemesis, and after Lou Landers (Christopher McDonald) is caught in the middle of an experiment gone horribly awry, he develops the power to leech the life force out of anyone he meets and becomes the villainous Hourglass. Intent on achieving immortality, the Hourglass attempts to gather as much life force as possible as the noble Dragonfly sets out to take down his archenemy and realize his destiny as a true hero. Craig Mazin writes and directs this low-flying spoof.<br /><br />featuring Tracy Morgan, Pamela Anderson, Leslie Nielsen, Marion Ross, Jeffrey Tambor, and Regina Hall.<br /><br />Hell Superhero Movie may earn some merit in the fact that it's a hell of a lot better than Meet the Spartans and Epic Movie. But with great responsibility comes one of the worst outings of 2008 to date. Laughless but a little less irritating than Meet the Spartans. And in the same sense much more forgettable than meet the Spartans. But maybe that's a good reason. There are still some of us trying to scrape away the stain that was Meet the Spartans from our memory.<br /><br />My final verdict? Avoid, unless you're one of thoses people who enjoy such car crash cinema. As bad as Date Movie and Scary Movie 2 but not quite as bad as Meet the Spartans or Epic Movie. Super Villain.
# Poor Shirley MacLaine tries hard to lend some gravitas to this mawkish, gag-inducing "feel-good" movie, but she's trampled by the run-away sentimentality of a film that's not the least bit grounded in reality.<br /><br />This was directed by Curtis Hanson? Did he have a lobotomy since we last heard from him? Hanson can do effective drama sprinkled with comedy, as evidenced by "Wonder Boys." So I don't know what happened to him here. This is the kind of movie that doesn't want to accept that life is messy and fussy, and that neat, tidy endings (however implausible they might be) might make for a nice closing shot, but come across as utterly phony if the people watching the film have been through anything remotely like what the characters in the film go through.<br /><br />My wife and I made a game of calling out the plot points before they occurred -- e.g. "the old man's going to teach her to read and then drop dead." Bingo! This is one of those movies where the characters give little speeches summarizing their emotional problems, making you wonder why they still have emotional problems if they're that aware of what's causing them. Toni Collette (a fine actress, by the way, and one of my favorites if not given a lot to work with here), gives a speech early on about why she buys so many shoes and never wears them, spelling out in flashing neon the film's awkward connecting motif. At that moment, I knew what I was in for, and the film was a downward spiral from there.<br /><br />Grade: C-

# %%
import torch.nn as nn
import math

class TEmbedding(nn.Module):
  def __init__(self, num_embeddings, hidden_dim, seq_length=1024, padding_idx=0):
    super(TEmbedding, self).__init__()
    
    self.num_embeddings = num_embeddings
    self.hidden_dim=hidden_dim
    self.seq_length = seq_length
    self.padding_idx = padding_idx

    self.embedding = nn.Embedding(num_embeddings, hidden_dim, padding_idx)
    self.pos_embeds  = nn.Parameter(torch.zeros(1, self.seq_length, self.hidden_dim))

    self.cls = nn.Parameter(torch.zeros(1, 1, self.hidden_dim)) #!!!!!!! INIT WITH ANOTHER VALUE IF REQUIRED

  def forward(self, input):
    batch_size, seq_len = input.shape
    
    embed = self.embedding(input)
    embed = embed + self.pos_embeds
    embed = torch.cat([ self.cls.expand(batch_size, 1, -1), embed ], axis=1)

    return embed
    

class TAttention(nn.Module):
  def __init__(self, hidden_dim, num_heads, dropout_rate):
    super(TAttention, self).__init__()
    self.hidden_dim=hidden_dim
    self.num_heads =num_heads
    
    assert not hidden_dim % num_heads
    
    self.head_dim =hidden_dim // num_heads

    self.q = nn.Linear(self.hidden_dim, self.hidden_dim)
    self.k = nn.Linear(self.hidden_dim, self.hidden_dim)
    self.v = nn.Linear(self.hidden_dim, self.hidden_dim)

    self.lin = nn.Linear(self.hidden_dim, self.hidden_dim)

    self.dropout = nn.Dropout(dropout_rate)

  def split_heads(self, x):
    new_shape = x.shape[:-1] + (self.num_heads, self.head_dim)
    x = x.view(* new_shape)
    return x.permute(0, 2, 1, 3)

  def forward(self, x, losses=[]):
    q = self.q(x)
    k = self.k(x)
    v = self.v(x)

    q, k, v = self.split_heads(q), self.split_heads(k), self.split_heads(v)
    q = torch.mul(q, 1. / torch.sqrt(torch.tensor(self.hidden_dim)))

    qk = torch.matmul(q, k.transpose(-1, -2))
    qk = nn.Softmax(dim=-1)(qk)

    def assertion_function(tsr):
      tsr = torch.sum(tsr, axis=-1)
      tsr = tsr - torch.ones_like(tsr)
      return torch.max(torch.abs(tsr)) < 1e-5

    assert assertion_function(qk)

    qk = self.dropout(qk) #Like in TF implementation; could be done before Softmax by random -inf addition

    out = torch.matmul(qk, v)
    out = out.permute(0, 2, 1, 3)

    new_shape = out.shape[:-2] + (self.hidden_dim,)

    out = out.reshape(* new_shape)

    out = self.lin(out)

    return out

class HWLinear(nn.Module):
  def __init__(self, num_heads, input_dim, output_dim, use_bias):
    super(HWLinear, self).__init__()
    
    self.use_bias = use_bias
    if use_bias:
      self.bias   = nn.Parameter(torch.zeros( (1, num_heads, 1, output_dim)))

    self.weight = nn.Parameter(torch.empty( (num_heads, input_dim, output_dim)))

    def he_init(m):
      s =  np.sqrt( 2. / input_dim )
      m.data.normal_(0, s)

    he_init(self.weight)

  def forward(self, x):
    x = torch.matmul(x, self.weight)
    if self.use_bias:
      x += self.bias
    return x

class Lambda(nn.Module):
  def __init__(self, lambda_, objects=None):
      super(Lambda, self).__init__()
      self.lambda_ = lambda_
      self.objects = objects

  def forward(self, x):
    if self.objects is not None:
      return self.lambda_(self.objects, x)
    return self.lambda_(x)

class LKAAttention(nn.Module):
  def __init__(self, hidden_dim, num_heads, dropout_rate):
    super(LKAAttention, self).__init__()
    self.hidden_dim=hidden_dim
    self.num_heads =num_heads

    assert not hidden_dim % num_heads
    
    self.head_dim =hidden_dim // num_heads
    
    self.q = nn.Linear(self.hidden_dim, self.hidden_dim)
    self.k = nn.Linear(self.hidden_dim, self.hidden_dim)
    self.v = nn.Linear(self.hidden_dim, self.hidden_dim)

    #self.lka = nn.Sequential(
    #  nn.Linear(self.head_dim, self.head_dim), nn.GELU(),
    #  nn.Linear(self.head_dim, self.head_dim), nn.Softplus(beta=2.5),
    #)

    #256, 4, 16, 1024
    #256, 64, 1, 1024
    class AMGOLU(nn.Module):
      def __init__(self, num_heads, hidden_dim, gate_rank, dropout_rate, gate_nonlinearity, kernel_nonlinearity, use_bias=False):
        super(AMGOLU, self).__init__()

        self.head_dim = hidden_dim // num_heads
        self.num_heads= num_heads
        
        self.orth_weight = HWLinear(num_heads, self.head_dim, self.head_dim, use_bias)
        self.orth_weight.weight = nn.Parameter(torch.stack([ nn.init.orthogonal_(torch.empty((self.head_dim, self.head_dim))) for _ in range(num_heads) ], dim=0))

        self.gate_weight_a = HWLinear(num_heads, self.head_dim, gate_rank, use_bias)
        self.gate_weight_b = HWLinear(num_heads, gate_rank, self.head_dim, use_bias)

        self.kernel_nonlinearity = kernel_nonlinearity
        self.gate_nonlinearity   = gate_nonlinearity

        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
      x, losses = x
      x = self.dropout(x)

      forward_info = self.orth_weight(x)
      forward_info = self.kernel_nonlinearity(forward_info)

      gate_info = self.gate_weight_a(x)
      gate_info = self.gate_weight_b(gate_info)
      gate_info = self.gate_nonlinearity(gate_info)

      x = forward_info * gate_info
      
      loss = torch.eye(self.head_dim, device=self.orth_weight.weight.device).unsqueeze(0).expand(self.num_heads, -1, -1)
      loss = nn.MSELoss()(torch.matmul(self.orth_weight.weight, self.orth_weight.weight.transpose(-1, -2)), loss)
      loss *= 0.1

      losses.append(loss)

      return x, losses



    class GatedOrthoKernel(nn.Module):
      def __init__(self, num_heads, hidden_dim, dropout_rate=0.1, gate_nonlinearity=nn.Sigmoid(), kernel_nonlinearity=nn.Identity(), use_bias=False):
        super(GatedOrthoKernel, self).__init__()

        self.head_dim = hidden_dim // num_heads
        self.num_heads = num_heads

        self.orth_weight = HWLinear(num_heads, self.head_dim, self.head_dim, use_bias)
        self.orth_weight.weight = nn.Parameter(torch.stack([ nn.init.orthogonal_(torch.empty((self.head_dim, self.head_dim))) for _ in range(num_heads) ], dim=0))
        self.gate_weight = HWLinear(num_heads, self.head_dim, self.head_dim, use_bias)

        self.kernel_nonlinearity = kernel_nonlinearity
        self.gate_nonlinearity   = gate_nonlinearity

        self.dropout = nn.Dropout(dropout_rate)

      def forward(self, x):
        x, losses = x
        x = self.dropout(x)

        x = self.kernel_nonlinearity(self.orth_weight(x)) * self.gate_nonlinearity(self.gate_weight(x))
        
        loss = torch.eye(self.head_dim, device=self.orth_weight.weight.device).unsqueeze(0).expand(self.num_heads, -1, -1)
        loss = nn.MSELoss()(torch.matmul(self.orth_weight.weight, self.orth_weight.weight.transpose(-1, -2)), loss)
        loss *= 0.1

        losses.append(loss)

        return x, losses


    class HeadWiseFF(nn.Module):
      def __init__(self, num_heads, hidden_dim, dropout_rate, nonlinearity=nn.Identity(), use_bias=False, residual=False):
        super(HeadWiseFF, self).__init__()
        
        head_dim = hidden_dim // num_heads

        self.bias   = nn.Parameter(torch.empty( (1, num_heads, 1, head_dim)))
        self.dropout= nn.Dropout(dropout_rate)
        self.use_bias = use_bias

        #self.weight = nn.Parameter(torch.empty( (num_heads, head_dim, head_dim)))
        #nn.init.kaiming_uniform_(self.weight, a=math.sqrt(5))

        #Orthogonal initialization
        #Workaround with torch.stack, since Torch initializes a tensor as orthgonal by flattening its trailing dims and QR-factorizing the resulting 2d
        
        self.weight = torch.stack([ nn.init.orthogonal_(torch.empty((head_dim, head_dim))) for _ in range(num_heads) ], dim=0)
        self.weight = nn.Parameter(self.weight)

        bound = 1 / math.sqrt(head_dim)
        nn.init.uniform_(self.bias, -bound, bound)

        self.nonlinearity = nonlinearity
        self.residual= residual

      def forward(self, x):
        
        x, losses = x

        bs, hd, seq, hdim = x.shape
        y = self.dropout(x)
        y = torch.matmul(y, self.weight) #BS, HD, SEQ, HDIM
        if self.use_bias:
          y += self.bias
        y = self.nonlinearity(y)

        loss = torch.eye(hdim, device=self.weight.device).unsqueeze(0).expand(* self.weight.shape)
        loss = nn.MSELoss()(torch.matmul(self.weight, self.weight.transpose(-1, -2)), loss)
        loss *= 0.1

        losses.append(loss)

        if self.residual:
          return x + y, losses
        return y, losses

    class VampKernel(nn.Module):
      def __init__(self, num_heads, hidden_dim, latent_dim, num_pseudoinputs, nonlinearity=nn.Softplus(), use_bias=True):
        super(VampKernel, self).__init__()

        head_dim = hidden_dim // num_heads
        self.head_dim = head_dim
        self.use_bias = use_bias
        self.num_heads= num_heads
        self.nonlinearity=nonlinearity

        #Encoder q(z2 | x)
        self.q_z2_x = nn.Sequential(
            HWLinear(num_heads, head_dim, latent_dim, use_bias),
            nn.GELU()
        )

        self.q_z2_mean    = HWLinear(num_heads, latent_dim, latent_dim, use_bias)
        self.q_z2_log_var = nn.Sequential(
            HWLinear(num_heads, latent_dim, latent_dim, use_bias),
            Lambda(lambda x: torch.tanh(x) * 4.0 - 2.0)
        )

        #Encoder q(z1 | x, z2)
        self.q_z1_x = nn.Sequential(
            HWLinear(num_heads, head_dim, latent_dim, use_bias),
            nn.GELU()
        )

        self.q_z1_z2 = nn.Sequential(
            HWLinear(num_heads, latent_dim, latent_dim, use_bias),
            nn.GELU()
        )

        #self.q_z1_joint = HWLinear(num_heads, latent_dim * 2, latent_dim, use_bias)

        self.q_z1_mean   = HWLinear(num_heads, latent_dim * 2, latent_dim, use_bias)
        self.q_z1_log_var= nn.Sequential(
            HWLinear(num_heads, latent_dim * 2, latent_dim, use_bias),
            Lambda(lambda x: torch.tanh(x) * 4.0 - 2.0)
        )

        #Decoder p(z1 | z2)
        self.p_z1_z2_mean = HWLinear(num_heads, latent_dim, latent_dim, use_bias)
        self.p_z1_z2_log_var = nn.Sequential(
            HWLinear(num_heads, latent_dim, latent_dim, use_bias),
            Lambda(lambda x: torch.tanh(x) * 4.0 - 2.0)
        )

        #Decoder p(x | z1, z2)
        self.p_x_z1 = nn.Sequential(
            HWLinear(num_heads, latent_dim, latent_dim, use_bias),
            nn.GELU()
        )

        self.p_x_z2 = nn.Sequential(
            HWLinear(num_heads, latent_dim, latent_dim, use_bias),
            nn.GELU()
        )

        #self.p_x_joint = HWLinear(num_heads, latent_dim * 2, latent_dim, use_bias)
        self.p_x_mean  = HWLinear(num_heads, latent_dim * 2, head_dim, use_bias)

        #Pseudoinputs
        self.means = nn.Sequential(
            HWLinear(num_heads, num_pseudoinputs, head_dim, False),
            nn.Tanh(),
        )
        self.dummy = nn.Parameter(torch.stack([ torch.eye(num_pseudoinputs) ] * num_heads, dim=0), requires_grad=False)

      def reparameterize(self, mu, log_var):
        if self.training:
          return mu
        
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)

        return mu + eps * std

      def log_p_z2(self, z2):
        #TODO
        X = self.means(self.dummy)
        HD, C, HDIM = X.shape
        
        pseudo_z2 = self.q_z2_x(X)
        pseudo_z2_mean, pseudo_z2_log_var = self.q_z2_mean(pseudo_z2), self.q_z2_log_var(pseudo_z2)

        #z2 = BS x HD x SEQ x HDIM
        #pseudo = HD x C x HDIM
        
        #expand to BS x HD x SEQ x 1 x HDIM
        #epxnad to  1 x HD x   1 x C x HDIM
        z2 = z2.unsqueeze(-2)
        pseudo_z2_mean = pseudo_z2_mean.unsqueeze(0).unsqueeze(2)
        pseudo_z2_log_var = pseudo_z2_log_var.unsqueeze(0).unsqueeze(2)

        return self.log_Normal_diag(z2, pseudo_z2_mean, pseudo_z2_log_var)
        

      def log_Normal_diag(self, x, mean, log_var, reduction=torch.mean):
          log_normal = -0.5 * ( log_var + torch.pow(x - mean, 2) / torch.exp(log_var) )
          return reduction( log_normal )

      def add_losses(self, losses, z1, z2, z1_p_mean, z1_p_logvar, z1_q_mean, z1_q_logvar, z2_q_mean, z2_q_logvar):
        #Reconstruction if needed
        #...

        #KLD
        log_p_z1 = self.log_Normal_diag(z1, z1_p_mean, z1_p_logvar)
        log_q_z1 = self.log_Normal_diag(z1, z1_q_mean, z1_q_logvar)
        log_p_z2 = self.log_p_z2(z2)
        log_q_z2 = self.log_Normal_diag(z2, z2_q_mean, z2_q_logvar)

        kld = -(log_p_z1 + log_p_z2 - log_q_z1 - log_q_z2)
        losses.append(kld)

      def forward(self, x):
        x, losses = x

        z2 = self.q_z2_x(x)
        z2_mean, z2_log_var = self.q_z2_mean(z2), self.q_z2_log_var(z2)
        z2 = self.reparameterize(z2_mean, z2_log_var)

        z1 = self.q_z1_x(x)
        z1_z2 = self.q_z1_z2(z2)
        z1 = torch.cat([ z1, z1_z2 ], dim=-1)
        z1_mean, z1_log_var = self.q_z1_mean(z1), self.q_z1_log_var(z1)
        z1 = self.reparameterize(z1_mean, z1_log_var)

        z1_p_mean, z1_p_logvar = self.p_z1_z2_mean(z2), self.p_z1_z2_log_var(z2)

        self.add_losses(losses, z1, z2, z1_p_mean, z1_p_logvar, z1_mean, z1_log_var, z2_mean, z2_log_var)
        
        x_z1 = self.p_x_z1(z1)
        x_z2 = self.p_x_z2(z2)

        output = torch.cat([ z_x1, x_z2 ], dim=-1)
        output = self.p_x_mean(output)

        self.add_losses(losses, z1, z2, z1_p_mean, z1_p_logvar, z1_mean, z1_log_var, z2_mean, z2_log_var)

        return self.nonlinearity(output), losses

    class VariationalKernel(nn.Module):
      def __init__(self, num_heads, hidden_dim, latent_dim, nonlinearity=nn.Softplus(), use_bias=True):
        super(VariationalKernel, self).__init__()

        head_dim = hidden_dim // num_heads
        
        self.z_mean = HWLinear(num_heads, head_dim, latent_dim, use_bias)
        self.z_log_var = nn.Sequential(
            HWLinear(num_heads, head_dim, latent_dim, use_bias),
            Lambda(lambda x: torch.tanh(x) * 4.0 - 2.0)
        )

        self.out = HWLinear(num_heads, latent_dim, head_dim, use_bias)
        self.nonlinearity = nonlinearity

      def reparameterize(self, mu, log_var):
        if self.training:
          return mu
        
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)

        return mu + eps * std

      def add_kld(self, z_mean, z_log_var, losses, reduction=torch.mean):
        _, hd, _, _ = z_mean.shape

        for i in range(hd):
          kl_div = -0.5 * reduction(1 + z_log_var[:, i, :, :] - z_mean[:, i, :, :].pow(2) - z_log_var[:, i, :, :].exp())
          losses.append(kl_div)

      def forward(self, x):
        x, losses = x
        
        z_mean   = self.z_mean(x)
        z_log_var= self.z_log_var(x)

        z = self.reparameterize(z_mean, z_log_var)
        
        out = self.out(z)

        self.add_kld(z_mean, z_log_var, losses)

        ###############################
        return self.nonlinearity(out), losses
        ###############################

        ###############################
        #rec_loss = nn.MSELoss()(out, x)
        #losses.append(rec_loss)
        
        #return self.nonlinearity(z), losses
        ################################

    self.lka = nn.Sequential(
        #HeadWiseFF(self.num_heads, self.hidden_dim, dropout_rate, nn.Tanh(), use_bias=True),
        #HeadWiseFF(self.num_heads, self.hidden_dim, dropout_rate, nn.Softplus()),
        
        #VariationalKernel(self.num_heads, self.hidden_dim, self.head_dim // 2)
        #VampKernel(self.num_heads, self.hidden_dim, self.head_dim // 2, 512, nn.Softplus(), False)
        
        #GatedOrthoKernel(self.num_heads, self.hidden_dim, dropout_rate, gate_nonlinearity=nn.Sigmoid(), kernel_nonlinearity=nn.Identity(), use_bias=False),
        HeadWiseFF(self.num_heads, self.hidden_dim, dropout_rate, nn.GELU(), use_bias=False),
        GatedOrthoKernel(self.num_heads, self.hidden_dim, dropout_rate, gate_nonlinearity=nn.Sigmoid(), kernel_nonlinearity=nn.Identity(), use_bias=False),
        GatedOrthoKernel(self.num_heads, self.hidden_dim, dropout_rate, gate_nonlinearity=nn.Sigmoid(), kernel_nonlinearity=nn.Softplus(), use_bias=False),
        #Lambda(lambda o, x: (o['nonlinearity'](x[0]), x[1]), { 'nonlinearity' : nn.Softplus() })
    )

    self.lin = nn.Linear(self.hidden_dim, self.hidden_dim)

    self.dropout = nn.Dropout(dropout_rate)

  def split_heads(self, x):
    new_shape = x.shape[:-1] + (self.num_heads, self.head_dim)
    x = x.view(* new_shape)
    return x.permute(0, 2, 1, 3)

  def forward(self, x, losses=[]):
    q = self.q(x)
    k = self.k(x)
    v = self.v(x)

    q, k, v = self.split_heads(q), self.split_heads(k), self.split_heads(v)
    #BS x HEADS x SEQ x HEAD_DIM
    
    q, _ = self.lka((q, losses))
    k, _ = self.lka((k, losses)) #Use this for var kernel

    q = q / math.sqrt(self.head_dim)
    k = k / math.sqrt(self.head_dim)

    numerator = torch.matmul(k.unsqueeze(-1), v.unsqueeze(-2))
    numerator = numerator.sum(axis=2)
    numerator = torch.matmul(q, numerator)
    
    denominator = k.sum(axis=2).unsqueeze(-1)
    denominator = q.matmul(denominator)

    out = numerator / denominator
    out = out.permute(0, 2, 1, 3)
    
    #TODO: INSERT DROPOUT
    
    new_shape = out.shape[:-2] + (self.hidden_dim,)
    out = out.reshape(* new_shape)

    out = self.lin(out)

    return out

class FtAttention(nn.Module):
  def __init__(self, *args, **kwargs):
    super(FtAttention, self).__init__()

  def forward(self, x, losses=[]):
    return torch.fft.fft(torch.fft.fft(x, dim=-1), dim=-2).real

class TBlock(nn.Module):
  def __init__(self, hidden_dim, inter_dim, num_heads, dropout_rate):
    super(TBlock, self).__init__()

    self.hidden_dim = hidden_dim
    self.inter_dim  = inter_dim

    self.layernorm_input = nn.LayerNorm(hidden_dim, eps=1e-6)
    self.layernorm_inter = nn.LayerNorm(hidden_dim, eps=1e-6)

    self.attention = TAttention(hidden_dim, num_heads, dropout_rate)

    self.ffn       = nn.Sequential(
        nn.Linear(hidden_dim, inter_dim), nn.GELU(), nn.Dropout(dropout_rate),
        nn.Linear(inter_dim, hidden_dim), nn.GELU(), nn.Dropout(dropout_rate),
    )


  def forward(self, input, losses=[]):
    x = self.layernorm_input(input)
    x = self.attention(x, losses)

    x = input + x

    y = self.layernorm_inter(x)
    x = self.ffn(y) + x

    return x

class TClassifier(nn.Module):
  def __init__(self, classes, hidden_dim, inter_dim, dropout_rate):
    super(TClassifier, self).__init__()

    self.layernorm = nn.LayerNorm(hidden_dim, eps=1e-6)
    self.dropout   = nn.Dropout(dropout_rate)

    self.ffn       = nn.Sequential(
        nn.Linear(hidden_dim, inter_dim), nn.GELU(),
    )
    self.output    = nn.Linear(inter_dim, classes)

  def forward(self, x):
    x = self.layernorm(x)
    x = x[:, 0, :]
    x = self.dropout(x)

    x = self.ffn(x)
    logits = self.output(x)

    return logits

class Transformer(nn.Module):
  def __init__(self, classes, num_embeddings, seq_len, hidden_dim=64, num_heads=4, num_blocks=8, output_units=512, internal_dropout_rate=0.1, output_dropout_rate=0.5):
    super(Transformer, self).__init__()

    inter_dim = 2 * hidden_dim
    
    self.embed_layer = TEmbedding(num_embeddings, hidden_dim, seq_len)
    self.blocks      = nn.ModuleList([ TBlock(hidden_dim, inter_dim, num_heads, internal_dropout_rate) for _ in range(num_blocks) ])
    self.classifier  = TClassifier(classes, hidden_dim, output_units, output_dropout_rate)

  def forward(self, pixel_values):
    additional_losses = []

    x = self.embed_layer(pixel_values)
    
    for block in self.blocks:
      x = block(x, additional_losses)
    
    x = self.classifier(x)

    return x, additional_losses

# %%
def num_parameters(model):
  return sum(list(map(
      lambda x: np.prod(x[1].shape), model.named_parameters()
  )))

n_classes = 2

def model_factory():
  model = Transformer(
    classes   =n_classes,
    num_embeddings=encoder.vocab_size,
    seq_len=max_length,
    hidden_dim=256,
    num_heads =4,
    num_blocks=4,
    output_units=1024,
    internal_dropout_rate=0.1,
    output_dropout_rate=0.0
  ).cuda()
  
  orig_count = num_parameters(model)

  for block in model.blocks:
    #block.attention = FtAttention()
    block.attention = LKAAttention(256, 4, 0.1).cuda()
    ...
  
  new_count = num_parameters(model)
  print(f'Original model {orig_count} params, new model {new_count} params, ratio {new_count / orig_count:.3}')

  return model

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import LambdaLR

def get_schedule(warmup_steps):
  def lr_schedule(step):
    return 1.0 * np.minimum(1.0, step / warmup_steps) / np.sqrt(np.maximum(step, warmup_steps))

  return lr_schedule

lr=0.05
weight_decay=0.1
warmup=8000

def training_setup():
  model = model_factory()
  criterion = nn.CrossEntropyLoss().cuda()
  optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
  schedule_func = get_schedule(warmup)
  scheduler = LambdaLR(optimizer, schedule_func)

  return model, criterion, optimizer, schedule_func, scheduler

_, _, _, schedule_func, _ = training_setup()

plt.plot([ lr * schedule_func(i) for i in range(len(train_dataset) // accumulation_steps * 25) ])
# Out:
# Original model 3464194 params, new model 3792898 params, ratio 1.09

# %%
import time

def save_model(model, optimizer, name='/content/drive/MyDrive/Work/Misc/lka-mini-base.tar'):
  torch.save({
              'model_state_dict': model.state_dict(),
              'optimizer_state_dict': optimizer.state_dict(),
              }, name)

def progress_bar(len, total, current):
  current_scaled = int(round(len * current / total))

  s = '[' + '=' * (current_scaled - 1)
  s += '>' if current != total else '='
  s += '-' * (len - current_scaled) + ']'

  return s

def accuracy(model_output, labels):
  model_output = model_output.argmax(dim=-1)

  return (labels == model_output).float().mean().cpu().numpy()

def train_model(model, name, train_dataset, valid_dataset, optimizer, criterion, scheduler, accumulation_steps, epochs, epoch_len=None, eps = 1e-6):
  
  best_acc = 0.0

  bnum = math.ceil(len(train_dataset) / accumulation_steps)
  train_dataset = train_dataset.shuffle(len(train_dataset), reshuffle_each_iteration=True)

  times_repeat = epochs if epoch_len is None else math.ceil(epochs * epoch_len / bnum)
  train_dataset = train_dataset.repeat(times_repeat)
  train_datagen = iter(train_dataset)
  
  if epoch_len is not None:
    bnum = epoch_len
  
  for epoch in range(epochs):  # loop over the dataset multiple times

      #epoch start timestamp
      t = time.time()

      running_loss = 0.0
      running_reg  = 0.0
      running_acc  = 0.0

      running_momentum = 0.99

      epoch_loss = [  ]
      epoch_reg  = [  ]
      epoch_acc  = [  ]

      model.train()

      print(f'Epoch {epoch}')

      process_inputs = lambda x: torch.Tensor(x.numpy()).to(torch.int64)

      for i in range(bnum):
          # zero the parameter gradients
          optimizer.zero_grad()

          #accumulate gradients for a certain amount of steps
          for k in range(accumulation_steps):
            # get the inputs; data is a list of [inputs, labels]

            try:
              data = next(train_datagen)
            except:
              break
            inputs, labels = data['inputs'], data['targets']
            inputs, labels = process_inputs(inputs), process_inputs(labels)
            inputs, labels = inputs.cuda(), labels.cuda()

            # forward + backward + optimize
            outputs, additional_losses = model(inputs)
            loss = criterion(outputs + eps, labels)

            additional_losses = sum(additional_losses) / len(additional_losses) if additional_losses else torch.Tensor([ 0.0 ]).cuda()
            ((loss + additional_losses) / accumulation_steps).backward()

            acc = accuracy(outputs, labels)

            running_loss = running_loss * running_momentum + (1 - running_momentum) * loss.item()
            running_loss_unb = running_loss / (1 - running_momentum ** (i * accumulation_steps + k + 1))

            running_acc  = running_acc  * running_momentum + (1 - running_momentum) * acc
            running_acc_unb = running_acc / (1 - running_momentum ** (i * accumulation_steps + k + 1))

            running_reg  = running_reg  * running_momentum + (1 - running_momentum) * additional_losses.item()
            running_reg_unb = running_reg / (1 - running_momentum ** (i * accumulation_steps + k + 1))

            epoch_loss.append(loss.item())
            epoch_acc.append(acc)
            epoch_reg.append(additional_losses.item())

          optimizer.step()

          pbar = progress_bar(20, bnum, i + 1)

          print(f'\r{pbar} {i + 1}/{bnum}:', end='')
          print(f' - running_loss: {running_loss_unb:.4f} - running_reg: {running_reg_unb:.6f} - running_acc: {running_acc_unb:.4f} - lr: {scheduler.get_last_lr()[0]:.5f}', end='')

          scheduler.step()
      
      epoch_loss = np.mean(epoch_loss)
      epoch_acc  = np.mean(epoch_acc)
      epoch_reg  = np.mean(epoch_reg)
      
      print(f' - epoch_loss: {epoch_loss:.4f} - epoch_reg: {epoch_reg:.6f} - epoch_acc: {epoch_acc:.4f}', end='')

      epoch_loss, epoch_acc, epoch_reg = [], [], []

      model.eval()
      valid_dataset.repeat()

      with torch.no_grad():
        for i, data in enumerate(iter(valid_dataset)):
          inputs, labels = data['inputs'], data['targets']
          inputs, labels = process_inputs(inputs), process_inputs(labels)
          inputs, labels = inputs.cuda(), labels.cuda()

          outputs, aux_losses = model(inputs)
          loss = criterion(outputs, labels)
          acc = accuracy(outputs, labels)
          aux_losses = sum(aux_losses) / len(aux_losses) if aux_losses else torch.Tensor([ 0.0 ]).cuda()

          epoch_loss.append(loss.item())
          epoch_acc.append(acc)
          epoch_reg.append(aux_losses.item())

      epoch_loss, epoch_acc, epoch_reg = np.mean(epoch_loss), np.mean(epoch_acc), np.mean(epoch_reg)

      if epoch_acc > best_acc:
        best_acc = epoch_acc
        save_model(model, optimizer, name)

      #epoch computing time
      t = time.time() - t

      print(f' - valid_loss: {epoch_loss:.4f} - valid_reg: {epoch_reg:.6f} - valid_acc: {epoch_acc:.4f} - epoch_time: {t:.4f} s')
 
  checkpoint = torch.load(name)
  return checkpoint

# %%
def test(model, criterion, test_dataset):
  epoch_loss, epoch_acc, epoch_reg = [], [], []

  model.eval()
  test_dataset.repeat()

  process_inputs = lambda x: torch.Tensor(x.numpy()).to(torch.int64)

  t = time.time()

  with torch.no_grad():
    for i, data in enumerate(iter(test_dataset)):
      inputs, labels = data['inputs'], data['targets']
      inputs, labels = process_inputs(inputs), process_inputs(labels)
      inputs, labels = inputs.cuda(), labels.cuda()

      outputs, aux_losses = model(inputs)
      loss = criterion(outputs, labels)
      acc = accuracy(outputs, labels)
      aux_losses = sum(aux_losses) / len(aux_losses) if aux_losses else torch.Tensor([ 0.0 ]).cuda()

      epoch_loss.append(loss.item())
      epoch_acc.append(acc)
      epoch_reg.append(aux_losses.item())

  t = time.time() - t

  epoch_loss, epoch_acc, epoch_reg = np.mean(epoch_loss), np.mean(epoch_acc), np.mean(epoch_reg)

  print(f' - test_loss: {epoch_loss:.4f} - test_reg: {epoch_reg:.6f} - test_acc: {epoch_acc:.4f} - test_time: {t:.4f} s')
  return epoch_loss, epoch_reg, epoch_acc

# %%
test_accuracy = [  ]

for i in range(5): ####!!!!!!!!!!!!!!
  path = 'model_to_test_' + str(i) + '.b'

  model, criterion, optimizer, schedule_func, scheduler = training_setup()

  checkpoint = train_model(model, path, train_dataset, valid_dataset, optimizer, criterion, scheduler, accumulation_steps, 100, 200)
  model.load_state_dict(checkpoint['model_state_dict'])
  
  _, _, acc = test(model, criterion, test_dataset)
  test_accuracy.append(acc)

test_accuracy = np.mean(test_accuracy)

print(f'\nTotal accuracy: {test_accuracy:.4f}')
# Out:
# Original model 3464194 params, new model 3792898 params, ratio 1.09
# Epoch 0
# [====================] 200/200: - running_loss: 0.6935 - running_reg: 0.000000 - running_acc: 0.5144 - lr: 0.00001 - epoch_loss: 0.6949 - epoch_reg: 0.000000 - epoch_acc: 0.5063 - valid_loss: 0.6949 - valid_reg: 0.000000 - valid_acc: 0.5136 - epoch_time: 182.1042 s
# Epoch 1
# [====================] 200/200: - running_loss: 0.6952 - running_reg: 0.000000 - running_acc: 0.5058 - lr: 0.00003 - epoch_loss: 0.6954 - epoch_reg: 0.000000 - epoch_acc: 0.5117 - valid_loss: 0.6958 - valid_reg: 0.000000 - valid_acc: 0.5061 - epoch_time: 171.9173 s
# Epoch 2
# [====================] 200/200: - running_loss: 0.6954 - running_reg: 0.000000 - running_acc: 0.5077 - lr: 0.00004 - epoch_loss: 0.6950 - epoch_reg: 0.000000 - epoch_acc: 0.5141 - valid_loss: 0.6985 - valid_reg: 0.000000 - valid_acc: 0.4977 - epoch_time: 172.4620 s
# Epoch 3
# [====================] 200/200: - running_loss: 0.6930 - running_reg: 0.000000 - running_acc: 0.5219 - lr: 0.00006 - epoch_loss: 0.6943 - epoch_reg: 0.000000 - epoch_acc: 0.5156 - valid_loss: 0.6970 - valid_reg: 0.000000 - valid_acc: 0.5001 - epoch_time: 172.6526 s
# Epoch 4
# [====================] 200/200: - running_loss: 0.6933 - running_reg: 0.000000 - running_acc: 0.5140 - lr: 0.00007 - epoch_loss: 0.6946 - epoch_reg: 0.000000 - epoch_acc: 0.5048 - valid_loss: 0.6927 - valid_reg: 0.000000 - valid_acc: 0.5090 - epoch_time: 172.5622 s
# Epoch 5
# [====================] 200/200: - running_loss: 0.6964 - running_reg: 0.000000 - running_acc: 0.5149 - lr: 0.00008 - epoch_loss: 0.6957 - epoch_reg: 0.000000 - epoch_acc: 0.5116 - valid_loss: 0.7002 - valid_reg: 0.000000 - valid_acc: 0.5060 - epoch_time: 172.6955 s
# Epoch 6
# [====================] 200/200: - running_loss: 0.6968 - running_reg: 0.000001 - running_acc: 0.5126 - lr: 0.00010 - epoch_loss: 0.6947 - epoch_reg: 0.000001 - epoch_acc: 0.5161 - valid_loss: 0.7025 - valid_reg: 0.000001 - valid_acc: 0.4999 - epoch_time: 172.7315 s
# Epoch 7
# [====================] 200/200: - running_loss: 0.6995 - running_reg: 0.000002 - running_acc: 0.5028 - lr: 0.00011 - epoch_loss: 0.6969 - epoch_reg: 0.000002 - epoch_acc: 0.5078 - valid_loss: 0.6947 - valid_reg: 0.000002 - valid_acc: 0.5137 - epoch_time: 173.0660 s
# Epoch 8
# [====================] 200/200: - running_loss: 0.6933 - running_reg: 0.000003 - running_acc: 0.5205 - lr: 0.00013 - epoch_loss: 0.6946 - epoch_reg: 0.000003 - epoch_acc: 0.5136 - valid_loss: 0.6937 - valid_reg: 0.000003 - valid_acc: 0.5105 - epoch_time: 172.7958 s
# Epoch 9
# [====================] 200/200: - running_loss: 0.6968 - running_reg: 0.000003 - running_acc: 0.4981 - lr: 0.00014 - epoch_loss: 0.6948 - epoch_reg: 0.000003 - epoch_acc: 0.5095 - valid_loss: 0.6947 - valid_reg: 0.000003 - valid_acc: 0.4999 - epoch_time: 172.9077 s
# Epoch 10
# [====================] 200/200: - running_loss: 0.6955 - running_reg: 0.000004 - running_acc: 0.5057 - lr: 0.00015 - epoch_loss: 0.6950 - epoch_reg: 0.000004 - epoch_acc: 0.5114 - valid_loss: 0.6928 - valid_reg: 0.000004 - valid_acc: 0.5001 - epoch_time: 172.7499 s
# Epoch 11
# [====================] 200/200: - running_loss: 0.6952 - running_reg: 0.000005 - running_acc: 0.5164 - lr: 0.00017 - epoch_loss: 0.6939 - epoch_reg: 0.000005 - epoch_acc: 0.5223 - valid_loss: 0.6923 - valid_reg: 0.000006 - valid_acc: 0.5118 - epoch_time: 172.0861 s
# Epoch 12
# [====================] 200/200: - running_loss: 0.6930 - running_reg: 0.000007 - running_acc: 0.5249 - lr: 0.00018 - epoch_loss: 0.6917 - epoch_reg: 0.000007 - epoch_acc: 0.5303 - valid_loss: 0.6947 - valid_reg: 0.000007 - valid_acc: 0.5104 - epoch_time: 172.2615 s
# Epoch 13
# [====================] 200/200: - running_loss: 0.6933 - running_reg: 0.000008 - running_acc: 0.5125 - lr: 0.00020 - epoch_loss: 0.6938 - epoch_reg: 0.000008 - epoch_acc: 0.5092 - valid_loss: 0.6921 - valid_reg: 0.000008 - valid_acc: 0.5152 - epoch_time: 172.4200 s
# Epoch 14
# [====================] 200/200: - running_loss: 0.6935 - running_reg: 0.000012 - running_acc: 0.5036 - lr: 0.00021 - epoch_loss: 0.6927 - epoch_reg: 0.000011 - epoch_acc: 0.5108 - valid_loss: 0.6917 - valid_reg: 0.000014 - valid_acc: 0.5231 - epoch_time: 172.7264 s
# Epoch 15
# [====================] 200/200: - running_loss: 0.6918 - running_reg: 0.000022 - running_acc: 0.5222 - lr: 0.00022 - epoch_loss: 0.6924 - epoch_reg: 0.000018 - epoch_acc: 0.5236 - valid_loss: 0.6950 - valid_reg: 0.000024 - valid_acc: 0.5088 - epoch_time: 172.9861 s
# Epoch 16
# [====================] 200/200: - running_loss: 0.6910 - running_reg: 0.000032 - running_acc: 0.5271 - lr: 0.00024 - epoch_loss: 0.6904 - epoch_reg: 0.000030 - epoch_acc: 0.5333 - valid_loss: 0.6781 - valid_reg: 0.000034 - valid_acc: 0.5760 - epoch_time: 173.0734 s
# Epoch 17
# [====================] 200/200: - running_loss: 0.6811 - running_reg: 0.000041 - running_acc: 0.5712 - lr: 0.00025 - epoch_loss: 0.6844 - epoch_reg: 0.000038 - epoch_acc: 0.5611 - valid_loss: 0.6818 - valid_reg: 0.000045 - valid_acc: 0.5691 - epoch_time: 172.6335 s
# Epoch 18
# [====================] 200/200: - running_loss: 0.6797 - running_reg: 0.000053 - running_acc: 0.5672 - lr: 0.00027 - epoch_loss: 0.6812 - epoch_reg: 0.000050 - epoch_acc: 0.5681 - valid_loss: 0.6696 - valid_reg: 0.000056 - valid_acc: 0.5981 - epoch_time: 172.6346 s
# Epoch 19
# [====================] 200/200: - running_loss: 0.6691 - running_reg: 0.000068 - running_acc: 0.5941 - lr: 0.00028 - epoch_loss: 0.6681 - epoch_reg: 0.000066 - epoch_acc: 0.5923 - valid_loss: 0.6699 - valid_reg: 0.000068 - valid_acc: 0.5837 - epoch_time: 172.5077 s
# Epoch 20
# [====================] 200/200: - running_loss: 0.6613 - running_reg: 0.000070 - running_acc: 0.6117 - lr: 0.00029 - epoch_loss: 0.6643 - epoch_reg: 0.000069 - epoch_acc: 0.5966 - valid_loss: 0.6664 - valid_reg: 0.000071 - valid_acc: 0.5944 - epoch_time: 174.1379 s
# Epoch 21
# [====================] 200/200: - running_loss: 0.6444 - running_reg: 0.000072 - running_acc: 0.6253 - lr: 0.00031 - epoch_loss: 0.6478 - epoch_reg: 0.000071 - epoch_acc: 0.6263 - valid_loss: 0.6567 - valid_reg: 0.000075 - valid_acc: 0.6151 - epoch_time: 174.7099 s
# Epoch 22
# [====================] 200/200: - running_loss: 0.6398 - running_reg: 0.000077 - running_acc: 0.6313 - lr: 0.00032 - epoch_loss: 0.6438 - epoch_reg: 0.000077 - epoch_acc: 0.6266 - valid_loss: 0.6883 - valid_reg: 0.000078 - valid_acc: 0.5996 - epoch_time: 174.5632 s
# Epoch 23
# [====================] 200/200: - running_loss: 0.6457 - running_reg: 0.000080 - running_acc: 0.6289 - lr: 0.00034 - epoch_loss: 0.6535 - epoch_reg: 0.000079 - epoch_acc: 0.6136 - valid_loss: 0.6432 - valid_reg: 0.000081 - valid_acc: 0.6300 - epoch_time: 174.7156 s
# Epoch 24
# [====================] 200/200: - running_loss: 0.6361 - running_reg: 0.000087 - running_acc: 0.6311 - lr: 0.00035 - epoch_loss: 0.6374 - epoch_reg: 0.000085 - epoch_acc: 0.6322 - valid_loss: 0.6399 - valid_reg: 0.000088 - valid_acc: 0.6288 - epoch_time: 174.7586 s
# Epoch 25
# [====================] 200/200: - running_loss: 0.6552 - running_reg: 0.000098 - running_acc: 0.6266 - lr: 0.00036 - epoch_loss: 0.6524 - epoch_reg: 0.000096 - epoch_acc: 0.6244 - valid_loss: 0.6393 - valid_reg: 0.000099 - valid_acc: 0.6344 - epoch_time: 174.8047 s
# Epoch 26
# [====================] 200/200: - running_loss: 0.6372 - running_reg: 0.000099 - running_acc: 0.6352 - lr: 0.00038 - epoch_loss: 0.6368 - epoch_reg: 0.000098 - epoch_acc: 0.6350 - valid_loss: 0.6394 - valid_reg: 0.000100 - valid_acc: 0.6372 - epoch_time: 174.7962 s
# Epoch 27
# [====================] 200/200: - running_loss: 0.6402 - running_reg: 0.000104 - running_acc: 0.6401 - lr: 0.00039 - epoch_loss: 0.6310 - epoch_reg: 0.000103 - epoch_acc: 0.6477 - valid_loss: 0.6377 - valid_reg: 0.000105 - valid_acc: 0.6384 - epoch_time: 174.8968 s
# Epoch 28
# [====================] 200/200: - running_loss: 0.6218 - running_reg: 0.000110 - running_acc: 0.6641 - lr: 0.00041 - epoch_loss: 0.6249 - epoch_reg: 0.000109 - epoch_acc: 0.6534 - valid_loss: 0.6313 - valid_reg: 0.000112 - valid_acc: 0.6467 - epoch_time: 174.7892 s
# Epoch 29
# [====================] 200/200: - running_loss: 0.6294 - running_reg: 0.000115 - running_acc: 0.6346 - lr: 0.00042 - epoch_loss: 0.6351 - epoch_reg: 0.000113 - epoch_acc: 0.6327 - valid_loss: 0.6750 - valid_reg: 0.000117 - valid_acc: 0.5780 - epoch_time: 174.7478 s
# Epoch 30
# [====================] 200/200: - running_loss: 0.6310 - running_reg: 0.000122 - running_acc: 0.6509 - lr: 0.00043 - epoch_loss: 0.6369 - epoch_reg: 0.000120 - epoch_acc: 0.6405 - valid_loss: 0.6332 - valid_reg: 0.000125 - valid_acc: 0.6475 - epoch_time: 174.7467 s
# Epoch 31
# [====================] 200/200: - running_loss: 0.6361 - running_reg: 0.000128 - running_acc: 0.6481 - lr: 0.00045 - epoch_loss: 0.6334 - epoch_reg: 0.000126 - epoch_acc: 0.6461 - valid_loss: 0.6492 - valid_reg: 0.000128 - valid_acc: 0.6185 - epoch_time: 174.9989 s
# Epoch 32
# [====================] 200/200: - running_loss: 0.6264 - running_reg: 0.000131 - running_acc: 0.6445 - lr: 0.00046 - epoch_loss: 0.6250 - epoch_reg: 0.000131 - epoch_acc: 0.6472 - valid_loss: 0.6282 - valid_reg: 0.000132 - valid_acc: 0.6498 - epoch_time: 175.2886 s
# Epoch 33
# [====================] 200/200: - running_loss: 0.6211 - running_reg: 0.000137 - running_acc: 0.6588 - lr: 0.00048 - epoch_loss: 0.6200 - epoch_reg: 0.000135 - epoch_acc: 0.6595 - valid_loss: 0.6290 - valid_reg: 0.000141 - valid_acc: 0.6539 - epoch_time: 174.9298 s
# Epoch 34
# [====================] 200/200: - running_loss: 0.6239 - running_reg: 0.000144 - running_acc: 0.6553 - lr: 0.00049 - epoch_loss: 0.6242 - epoch_reg: 0.000143 - epoch_acc: 0.6550 - valid_loss: 0.6369 - valid_reg: 0.000143 - valid_acc: 0.6429 - epoch_time: 174.9580 s
# Epoch 35
# [====================] 200/200: - running_loss: 0.6124 - running_reg: 0.000146 - running_acc: 0.6676 - lr: 0.00050 - epoch_loss: 0.6197 - epoch_reg: 0.000145 - epoch_acc: 0.6591 - valid_loss: 0.6319 - valid_reg: 0.000147 - valid_acc: 0.6458 - epoch_time: 174.7788 s
# Epoch 36
# [====================] 200/200: - running_loss: 0.6568 - running_reg: 0.000170 - running_acc: 0.6154 - lr: 0.00052 - epoch_loss: 0.6432 - epoch_reg: 0.000161 - epoch_acc: 0.6275 - valid_loss: 0.6384 - valid_reg: 0.000174 - valid_acc: 0.6366 - epoch_time: 174.7884 s
# Epoch 37
# [====================] 200/200: - running_loss: 0.6301 - running_reg: 0.000180 - running_acc: 0.6529 - lr: 0.00053 - epoch_loss: 0.6304 - epoch_reg: 0.000176 - epoch_acc: 0.6441 - valid_loss: 0.6796 - valid_reg: 0.000186 - valid_acc: 0.6134 - epoch_time: 174.7564 s
# Epoch 38
# [====================] 200/200: - running_loss: 0.6279 - running_reg: 0.000183 - running_acc: 0.6435 - lr: 0.00054 - epoch_loss: 0.6316 - epoch_reg: 0.000183 - epoch_acc: 0.6486 - valid_loss: 0.6296 - valid_reg: 0.000184 - valid_acc: 0.6509 - epoch_time: 174.7327 s
# Epoch 39
# [====================] 200/200: - running_loss: 0.6141 - running_reg: 0.000186 - running_acc: 0.6669 - lr: 0.00056 - epoch_loss: 0.6234 - epoch_reg: 0.000186 - epoch_acc: 0.6525 - valid_loss: 0.6297 - valid_reg: 0.000186 - valid_acc: 0.6554 - epoch_time: 174.9650 s
# Epoch 40
# [====================] 200/200: - running_loss: 0.6296 - running_reg: 0.000185 - running_acc: 0.6460 - lr: 0.00055 - epoch_loss: 0.6228 - epoch_reg: 0.000184 - epoch_acc: 0.6545 - valid_loss: 0.6222 - valid_reg: 0.000186 - valid_acc: 0.6586 - epoch_time: 174.9468 s
# Epoch 41
# [====================] 200/200: - running_loss: 0.6273 - running_reg: 0.000185 - running_acc: 0.6432 - lr: 0.00055 - epoch_loss: 0.6202 - epoch_reg: 0.000186 - epoch_acc: 0.6527 - valid_loss: 0.6299 - valid_reg: 0.000186 - valid_acc: 0.6459 - epoch_time: 174.8769 s
# Epoch 42
# [====================] 200/200: - running_loss: 0.6195 - running_reg: 0.000194 - running_acc: 0.6579 - lr: 0.00054 - epoch_loss: 0.6206 - epoch_reg: 0.000191 - epoch_acc: 0.6605 - valid_loss: 0.6302 - valid_reg: 0.000192 - valid_acc: 0.6495 - epoch_time: 174.7854 s
# Epoch 43
# [====================] 200/200: - running_loss: 0.6169 - running_reg: 0.000197 - running_acc: 0.6688 - lr: 0.00053 - epoch_loss: 0.6140 - epoch_reg: 0.000195 - epoch_acc: 0.6677 - valid_loss: 0.6245 - valid_reg: 0.000198 - valid_acc: 0.6556 - epoch_time: 174.8694 s
# Epoch 44
# [====================] 200/200: - running_loss: 0.6161 - running_reg: 0.000201 - running_acc: 0.6671 - lr: 0.00053 - epoch_loss: 0.6124 - epoch_reg: 0.000201 - epoch_acc: 0.6661 - valid_loss: 0.6313 - valid_reg: 0.000201 - valid_acc: 0.6408 - epoch_time: 174.7601 s
# Epoch 45
# [====================] 200/200: - running_loss: 0.6116 - running_reg: 0.000207 - running_acc: 0.6719 - lr: 0.00052 - epoch_loss: 0.6196 - epoch_reg: 0.000205 - epoch_acc: 0.6602 - valid_loss: 0.6296 - valid_reg: 0.000208 - valid_acc: 0.6460 - epoch_time: 174.8940 s
# Epoch 46
# [====================] 200/200: - running_loss: 0.6152 - running_reg: 0.000206 - running_acc: 0.6534 - lr: 0.00052 - epoch_loss: 0.6200 - epoch_reg: 0.000208 - epoch_acc: 0.6575 - valid_loss: 0.6298 - valid_reg: 0.000205 - valid_acc: 0.6433 - epoch_time: 174.7301 s
# Epoch 47
# [====================] 200/200: - running_loss: 0.6072 - running_reg: 0.000214 - running_acc: 0.6727 - lr: 0.00051 - epoch_loss: 0.6092 - epoch_reg: 0.000212 - epoch_acc: 0.6706 - valid_loss: 0.6216 - valid_reg: 0.000216 - valid_acc: 0.6564 - epoch_time: 174.7396 s
# Epoch 48
# [====================] 200/200: - running_loss: 0.6355 - running_reg: 0.000233 - running_acc: 0.6407 - lr: 0.00051 - epoch_loss: 0.6198 - epoch_reg: 0.000224 - epoch_acc: 0.6589 - valid_loss: 0.6388 - valid_reg: 0.000239 - valid_acc: 0.6343 - epoch_time: 174.9597 s
# Epoch 49
# [====================] 200/200: - running_loss: 0.6020 - running_reg: 0.000232 - running_acc: 0.6675 - lr: 0.00050 - epoch_loss: 0.6108 - epoch_reg: 0.000234 - epoch_acc: 0.6616 - valid_loss: 0.6223 - valid_reg: 0.000232 - valid_acc: 0.6603 - epoch_time: 174.7913 s
# Epoch 50
# [====================] 200/200: - running_loss: 0.6203 - running_reg: 0.000233 - running_acc: 0.6618 - lr: 0.00050 - epoch_loss: 0.6148 - epoch_reg: 0.000233 - epoch_acc: 0.6639 - valid_loss: 0.6240 - valid_reg: 0.000237 - valid_acc: 0.6505 - epoch_time: 174.7710 s
# Epoch 51
# [====================] 200/200: - running_loss: 0.5991 - running_reg: 0.000235 - running_acc: 0.6778 - lr: 0.00049 - epoch_loss: 0.5993 - epoch_reg: 0.000235 - epoch_acc: 0.6798 - valid_loss: 0.6316 - valid_reg: 0.000236 - valid_acc: 0.6490 - epoch_time: 174.9131 s
# Epoch 52
# [====================] 200/200: - running_loss: 0.6057 - running_reg: 0.000237 - running_acc: 0.6695 - lr: 0.00049 - epoch_loss: 0.6017 - epoch_reg: 0.000237 - epoch_acc: 0.6741 - valid_loss: 0.6202 - valid_reg: 0.000235 - valid_acc: 0.6608 - epoch_time: 175.0388 s
# Epoch 53
# [====================] 200/200: - running_loss: 0.5936 - running_reg: 0.000245 - running_acc: 0.6846 - lr: 0.00048 - epoch_loss: 0.6062 - epoch_reg: 0.000242 - epoch_acc: 0.6753 - valid_loss: 0.6485 - valid_reg: 0.000244 - valid_acc: 0.6443 - epoch_time: 174.8626 s
# Epoch 54
# [====================] 200/200: - running_loss: 0.6070 - running_reg: 0.000255 - running_acc: 0.6698 - lr: 0.00048 - epoch_loss: 0.6076 - epoch_reg: 0.000252 - epoch_acc: 0.6702 - valid_loss: 0.6257 - valid_reg: 0.000258 - valid_acc: 0.6565 - epoch_time: 174.8736 s
# Epoch 55
# [====================] 200/200: - running_loss: 0.6075 - running_reg: 0.000256 - running_acc: 0.6709 - lr: 0.00047 - epoch_loss: 0.6077 - epoch_reg: 0.000255 - epoch_acc: 0.6725 - valid_loss: 0.6478 - valid_reg: 0.000258 - valid_acc: 0.6230 - epoch_time: 174.8714 s
# Epoch 56
# [====================] 200/200: - running_loss: 0.5849 - running_reg: 0.000265 - running_acc: 0.6979 - lr: 0.00047 - epoch_loss: 0.5942 - epoch_reg: 0.000263 - epoch_acc: 0.6881 - valid_loss: 0.6314 - valid_reg: 0.000262 - valid_acc: 0.6583 - epoch_time: 175.0351 s
# Epoch 57
# [====================] 200/200: - running_loss: 0.6050 - running_reg: 0.000260 - running_acc: 0.6701 - lr: 0.00046 - epoch_loss: 0.6045 - epoch_reg: 0.000261 - epoch_acc: 0.6695 - valid_loss: 0.6257 - valid_reg: 0.000262 - valid_acc: 0.6552 - epoch_time: 175.0383 s
# Epoch 58
# [====================] 200/200: - running_loss: 0.6068 - running_reg: 0.000271 - running_acc: 0.6604 - lr: 0.00046 - epoch_loss: 0.5995 - epoch_reg: 0.000267 - epoch_acc: 0.6761 - valid_loss: 0.6496 - valid_reg: 0.000274 - valid_acc: 0.6375 - epoch_time: 174.9366 s
# Epoch 59
# [====================] 200/200: - running_loss: 0.5868 - running_reg: 0.000279 - running_acc: 0.6879 - lr: 0.00046 - epoch_loss: 0.5886 - epoch_reg: 0.000277 - epoch_acc: 0.6902 - valid_loss: 0.6245 - valid_reg: 0.000279 - valid_acc: 0.6532 - epoch_time: 175.1305 s
# Epoch 60
# [====================] 200/200: - running_loss: 0.5967 - running_reg: 0.000286 - running_acc: 0.6756 - lr: 0.00045 - epoch_loss: 0.5967 - epoch_reg: 0.000285 - epoch_acc: 0.6750 - valid_loss: 0.6292 - valid_reg: 0.000287 - valid_acc: 0.6493 - epoch_time: 174.8887 s
# Epoch 61
# [====================] 200/200: - running_loss: 0.5936 - running_reg: 0.000281 - running_acc: 0.6835 - lr: 0.00045 - epoch_loss: 0.5962 - epoch_reg: 0.000282 - epoch_acc: 0.6822 - valid_loss: 0.6262 - valid_reg: 0.000286 - valid_acc: 0.6552 - epoch_time: 175.0007 s
# Epoch 62
# [====================] 200/200: - running_loss: 0.5895 - running_reg: 0.000290 - running_acc: 0.6810 - lr: 0.00045 - epoch_loss: 0.5917 - epoch_reg: 0.000289 - epoch_acc: 0.6842 - valid_loss: 0.6541 - valid_reg: 0.000292 - valid_acc: 0.6322 - epoch_time: 174.9766 s
# Epoch 63
# [====================] 200/200: - running_loss: 0.5808 - running_reg: 0.000297 - running_acc: 0.6990 - lr: 0.00044 - epoch_loss: 0.5828 - epoch_reg: 0.000296 - epoch_acc: 0.6941 - valid_loss: 0.6530 - valid_reg: 0.000299 - valid_acc: 0.6478 - epoch_time: 174.9780 s
# Epoch 64
# [====================] 200/200: - running_loss: 0.5829 - running_reg: 0.000307 - running_acc: 0.6921 - lr: 0.00044 - epoch_loss: 0.5806 - epoch_reg: 0.000303 - epoch_acc: 0.6941 - valid_loss: 0.6318 - valid_reg: 0.000310 - valid_acc: 0.6521 - epoch_time: 175.1322 s
# Epoch 65
# [====================] 200/200: - running_loss: 0.5876 - running_reg: 0.000309 - running_acc: 0.6895 - lr: 0.00044 - epoch_loss: 0.5840 - epoch_reg: 0.000308 - epoch_acc: 0.6936 - valid_loss: 0.6265 - valid_reg: 0.000309 - valid_acc: 0.6526 - epoch_time: 175.0296 s
# Epoch 66
# [====================] 200/200: - running_loss: 0.5759 - running_reg: 0.000314 - running_acc: 0.7092 - lr: 0.00043 - epoch_loss: 0.5813 - epoch_reg: 0.000311 - epoch_acc: 0.7009 - valid_loss: 0.6433 - valid_reg: 0.000318 - valid_acc: 0.6477 - epoch_time: 174.9698 s
# Epoch 67
# [====================] 200/200: - running_loss: 0.5663 - running_reg: 0.000323 - running_acc: 0.7035 - lr: 0.00043 - epoch_loss: 0.5605 - epoch_reg: 0.000323 - epoch_acc: 0.7077 - valid_loss: 0.6378 - valid_reg: 0.000326 - valid_acc: 0.6473 - epoch_time: 174.9822 s
# Epoch 68
# [====================] 200/200: - running_loss: 0.5618 - running_reg: 0.000332 - running_acc: 0.7060 - lr: 0.00043 - epoch_loss: 0.5641 - epoch_reg: 0.000330 - epoch_acc: 0.7072 - valid_loss: 0.6343 - valid_reg: 0.000345 - valid_acc: 0.6523 - epoch_time: 174.9955 s
# Epoch 69
# [====================] 200/200: - running_loss: 0.5753 - running_reg: 0.000339 - running_acc: 0.7042 - lr: 0.00042 - epoch_loss: 0.5661 - epoch_reg: 0.000340 - epoch_acc: 0.7145 - valid_loss: 0.6384 - valid_reg: 0.000341 - valid_acc: 0.6513 - epoch_time: 174.9692 s
# Epoch 70
# [====================] 200/200: - running_loss: 0.5485 - running_reg: 0.000345 - running_acc: 0.7213 - lr: 0.00042 - epoch_loss: 0.5512 - epoch_reg: 0.000343 - epoch_acc: 0.7208 - valid_loss: 0.6619 - valid_reg: 0.000344 - valid_acc: 0.6146 - epoch_time: 175.0659 s
# Epoch 71
# [====================] 200/200: - running_loss: 0.5412 - running_reg: 0.000361 - running_acc: 0.7310 - lr: 0.00042 - epoch_loss: 0.5392 - epoch_reg: 0.000354 - epoch_acc: 0.7311 - valid_loss: 0.6740 - valid_reg: 0.000366 - valid_acc: 0.6370 - epoch_time: 174.9945 s
# Epoch 72
# [====================] 200/200: - running_loss: 0.5287 - running_reg: 0.000373 - running_acc: 0.7390 - lr: 0.00041 - epoch_loss: 0.5460 - epoch_reg: 0.000372 - epoch_acc: 0.7311 - valid_loss: 0.6970 - valid_reg: 0.000375 - valid_acc: 0.6390 - epoch_time: 175.0775 s
# Epoch 73
# [====================] 200/200: - running_loss: 0.5520 - running_reg: 0.000390 - running_acc: 0.7232 - lr: 0.00041 - epoch_loss: 0.5440 - epoch_reg: 0.000387 - epoch_acc: 0.7247 - valid_loss: 0.6770 - valid_reg: 0.000390 - valid_acc: 0.6390 - epoch_time: 174.8954 s
# Epoch 74
# [====================] 200/200: - running_loss: 0.5253 - running_reg: 0.000395 - running_acc: 0.7482 - lr: 0.00041 - epoch_loss: 0.5225 - epoch_reg: 0.000393 - epoch_acc: 0.7439 - valid_loss: 0.6695 - valid_reg: 0.000396 - valid_acc: 0.6278 - epoch_time: 174.9883 s
# Epoch 75
# [====================] 200/200: - running_loss: 0.5095 - running_reg: 0.000412 - running_acc: 0.7539 - lr: 0.00041 - epoch_loss: 0.5085 - epoch_reg: 0.000407 - epoch_acc: 0.7558 - valid_loss: 0.7007 - valid_reg: 0.000410 - valid_acc: 0.6320 - epoch_time: 174.8242 s
# Epoch 76
# [====================] 200/200: - running_loss: 0.5211 - running_reg: 0.000416 - running_acc: 0.7442 - lr: 0.00040 - epoch_loss: 0.5175 - epoch_reg: 0.000414 - epoch_acc: 0.7444 - valid_loss: 0.7032 - valid_reg: 0.000416 - valid_acc: 0.6328 - epoch_time: 174.8499 s
# Epoch 77
# [====================] 200/200: - running_loss: 0.5039 - running_reg: 0.000427 - running_acc: 0.7595 - lr: 0.00040 - epoch_loss: 0.5060 - epoch_reg: 0.000424 - epoch_acc: 0.7541 - valid_loss: 0.6991 - valid_reg: 0.000424 - valid_acc: 0.6290 - epoch_time: 175.1377 s
# Epoch 78
# [====================] 200/200: - running_loss: 0.4900 - running_reg: 0.000442 - running_acc: 0.7675 - lr: 0.00040 - epoch_loss: 0.4923 - epoch_reg: 0.000434 - epoch_acc: 0.7642 - valid_loss: 0.7097 - valid_reg: 0.000445 - valid_acc: 0.6281 - epoch_time: 175.0631 s
# Epoch 79
# [====================] 200/200: - running_loss: 0.4854 - running_reg: 0.000463 - running_acc: 0.7642 - lr: 0.00040 - epoch_loss: 0.4761 - epoch_reg: 0.000458 - epoch_acc: 0.7742 - valid_loss: 0.7348 - valid_reg: 0.000465 - valid_acc: 0.6240 - epoch_time: 175.0838 s
# Epoch 80
# [====================] 200/200: - running_loss: 0.4878 - running_reg: 0.000473 - running_acc: 0.7719 - lr: 0.00039 - epoch_loss: 0.4841 - epoch_reg: 0.000472 - epoch_acc: 0.7697 - valid_loss: 0.7802 - valid_reg: 0.000474 - valid_acc: 0.6241 - epoch_time: 175.4745 s
# Epoch 81
# [====================] 200/200: - running_loss: 0.4892 - running_reg: 0.000481 - running_acc: 0.7602 - lr: 0.00039 - epoch_loss: 0.4898 - epoch_reg: 0.000479 - epoch_acc: 0.7611 - valid_loss: 0.7595 - valid_reg: 0.000482 - valid_acc: 0.6200 - epoch_time: 175.1710 s
# Epoch 82
# [====================] 200/200: - running_loss: 0.4427 - running_reg: 0.000498 - running_acc: 0.7924 - lr: 0.00039 - epoch_loss: 0.4571 - epoch_reg: 0.000491 - epoch_acc: 0.7881 - valid_loss: 0.8368 - valid_reg: 0.000508 - valid_acc: 0.6248 - epoch_time: 175.0291 s
# Epoch 83
# [====================] 200/200: - running_loss: 0.4450 - running_reg: 0.000510 - running_acc: 0.7965 - lr: 0.00039 - epoch_loss: 0.4555 - epoch_reg: 0.000509 - epoch_acc: 0.7850 - valid_loss: 0.8386 - valid_reg: 0.000512 - valid_acc: 0.6223 - epoch_time: 175.1111 s
# Epoch 84
# [====================] 200/200: - running_loss: 0.4852 - running_reg: 0.000523 - running_acc: 0.7666 - lr: 0.00038 - epoch_loss: 0.4691 - epoch_reg: 0.000520 - epoch_acc: 0.7775 - valid_loss: 0.7355 - valid_reg: 0.000520 - valid_acc: 0.6214 - epoch_time: 175.1077 s
# Epoch 85
# [====================] 200/200: - running_loss: 0.4412 - running_reg: 0.000530 - running_acc: 0.7943 - lr: 0.00038 - epoch_loss: 0.4574 - epoch_reg: 0.000527 - epoch_acc: 0.7880 - valid_loss: 0.7901 - valid_reg: 0.000529 - valid_acc: 0.6265 - epoch_time: 174.8946 s
# Epoch 86
# [====================] 200/200: - running_loss: 0.4260 - running_reg: 0.000548 - running_acc: 0.8033 - lr: 0.00038 - epoch_loss: 0.4243 - epoch_reg: 0.000543 - epoch_acc: 0.8048 - valid_loss: 0.7812 - valid_reg: 0.000550 - valid_acc: 0.6215 - epoch_time: 175.0462 s
# Epoch 87
# [====================] 200/200: - running_loss: 0.4433 - running_reg: 0.000559 - running_acc: 0.7956 - lr: 0.00038 - epoch_loss: 0.4343 - epoch_reg: 0.000553 - epoch_acc: 0.8008 - valid_loss: 0.7827 - valid_reg: 0.000568 - valid_acc: 0.6199 - epoch_time: 175.1573 s
# Epoch 88
# [====================] 200/200: - running_loss: 0.4528 - running_reg: 0.000556 - running_acc: 0.7925 - lr: 0.00037 - epoch_loss: 0.4445 - epoch_reg: 0.000560 - epoch_acc: 0.7970 - valid_loss: 0.7436 - valid_reg: 0.000553 - valid_acc: 0.6221 - epoch_time: 174.8983 s
# Epoch 89
# [====================] 200/200: - running_loss: 0.4177 - running_reg: 0.000557 - running_acc: 0.8087 - lr: 0.00037 - epoch_loss: 0.4306 - epoch_reg: 0.000557 - epoch_acc: 0.8028 - valid_loss: 0.8978 - valid_reg: 0.000560 - valid_acc: 0.6101 - epoch_time: 174.9227 s
# Epoch 90
# [====================] 200/200: - running_loss: 0.4116 - running_reg: 0.000578 - running_acc: 0.8115 - lr: 0.00037 - epoch_loss: 0.4062 - epoch_reg: 0.000574 - epoch_acc: 0.8169 - valid_loss: 0.7467 - valid_reg: 0.000575 - valid_acc: 0.6238 - epoch_time: 174.9589 s
# Epoch 91
# [====================] 200/200: - running_loss: 0.4003 - running_reg: 0.000586 - running_acc: 0.8159 - lr: 0.00037 - epoch_loss: 0.4070 - epoch_reg: 0.000582 - epoch_acc: 0.8159 - valid_loss: 0.8874 - valid_reg: 0.000592 - valid_acc: 0.5984 - epoch_time: 175.1239 s
# Epoch 92
# [====================] 200/200: - running_loss: 0.4252 - running_reg: 0.000598 - running_acc: 0.8093 - lr: 0.00037 - epoch_loss: 0.4167 - epoch_reg: 0.000594 - epoch_acc: 0.8095 - valid_loss: 0.7690 - valid_reg: 0.000601 - valid_acc: 0.6241 - epoch_time: 175.0377 s
# Epoch 93
# [====================] 200/200: - running_loss: 0.4052 - running_reg: 0.000611 - running_acc: 0.8190 - lr: 0.00036 - epoch_loss: 0.4132 - epoch_reg: 0.000607 - epoch_acc: 0.8127 - valid_loss: 0.9179 - valid_reg: 0.000623 - valid_acc: 0.6075 - epoch_time: 175.0964 s
# Epoch 94
# [====================] 200/200: - running_loss: 0.3828 - running_reg: 0.000630 - running_acc: 0.8307 - lr: 0.00036 - epoch_loss: 0.3873 - epoch_reg: 0.000626 - epoch_acc: 0.8255 - valid_loss: 0.8124 - valid_reg: 0.000632 - valid_acc: 0.6253 - epoch_time: 174.9685 s
# Epoch 95
# [====================] 200/200: - running_loss: 0.3719 - running_reg: 0.000625 - running_acc: 0.8318 - lr: 0.00036 - epoch_loss: 0.3796 - epoch_reg: 0.000627 - epoch_acc: 0.8264 - valid_loss: 0.8776 - valid_reg: 0.000625 - valid_acc: 0.6147 - epoch_time: 174.9937 s
# Epoch 96
# [====================] 200/200: - running_loss: 0.4033 - running_reg: 0.000631 - running_acc: 0.8175 - lr: 0.00036 - epoch_loss: 0.3924 - epoch_reg: 0.000627 - epoch_acc: 0.8255 - valid_loss: 0.8661 - valid_reg: 0.000636 - valid_acc: 0.6216 - epoch_time: 175.2395 s
# Epoch 97
# [====================] 200/200: - running_loss: 0.3678 - running_reg: 0.000639 - running_acc: 0.8405 - lr: 0.00036 - epoch_loss: 0.3927 - epoch_reg: 0.000638 - epoch_acc: 0.8248 - valid_loss: 0.8948 - valid_reg: 0.000634 - valid_acc: 0.6152 - epoch_time: 173.7641 s
# Epoch 98
# [====================] 200/200: - running_loss: 0.3778 - running_reg: 0.000652 - running_acc: 0.8320 - lr: 0.00036 - epoch_loss: 0.3710 - epoch_reg: 0.000647 - epoch_acc: 0.8359 - valid_loss: 0.8769 - valid_reg: 0.000656 - valid_acc: 0.6161 - epoch_time: 171.3537 s
# Epoch 99
# [====================] 200/200: - running_loss: 0.3793 - running_reg: 0.000666 - running_acc: 0.8291 - lr: 0.00035 - epoch_loss: 0.3790 - epoch_reg: 0.000666 - epoch_acc: 0.8291 - valid_loss: 0.9174 - valid_reg: 0.000664 - valid_acc: 0.6192 - epoch_time: 171.3785 s
#  - test_loss: 0.6202 - test_reg: 0.000235 - test_acc: 0.6608 - test_time: 94.3464 s
# Original model 3464194 params, new model 3792898 params, ratio 1.09
# Epoch 0
# [====================] 200/200: - running_loss: 0.6939 - running_reg: 0.000000 - running_acc: 0.5151 - lr: 0.00001 - epoch_loss: 0.6928 - epoch_reg: 0.000000 - epoch_acc: 0.5181 - valid_loss: 0.6909 - valid_reg: 0.000000 - valid_acc: 0.5221 - epoch_time: 190.9351 s
# Epoch 1
# [====================] 200/200: - running_loss: 0.6932 - running_reg: 0.000000 - running_acc: 0.5175 - lr: 0.00003 - epoch_loss: 0.6947 - epoch_reg: 0.000000 - epoch_acc: 0.5088 - valid_loss: 0.6927 - valid_reg: 0.000000 - valid_acc: 0.5107 - epoch_time: 173.9312 s
# Epoch 2
# [====================] 200/200: - running_loss: 0.6970 - running_reg: 0.000000 - running_acc: 0.5133 - lr: 0.00004 - epoch_loss: 0.6946 - epoch_reg: 0.000000 - epoch_acc: 0.5172 - valid_loss: 0.6912 - valid_reg: 0.000000 - valid_acc: 0.5230 - epoch_time: 174.1529 s
# Epoch 3
# [====================] 200/200: - running_loss: 0.6951 - running_reg: 0.000000 - running_acc: 0.5184 - lr: 0.00006 - epoch_loss: 0.6950 - epoch_reg: 0.000000 - epoch_acc: 0.5166 - valid_loss: 0.6989 - valid_reg: 0.000000 - valid_acc: 0.5001 - epoch_time: 173.9819 s
# Epoch 4
# [====================] 200/200: - running_loss: 0.6927 - running_reg: 0.000000 - running_acc: 0.5103 - lr: 0.00007 - epoch_loss: 0.6942 - epoch_reg: 0.000000 - epoch_acc: 0.5091 - valid_loss: 0.6918 - valid_reg: 0.000000 - valid_acc: 0.5275 - epoch_time: 174.7801 s
# Epoch 5
# [====================] 200/200: - running_loss: 0.6966 - running_reg: 0.000000 - running_acc: 0.4946 - lr: 0.00008 - epoch_loss: 0.6970 - epoch_reg: 0.000000 - epoch_acc: 0.4889 - valid_loss: 0.6928 - valid_reg: 0.000001 - valid_acc: 0.5063 - epoch_time: 174.7226 s
# Epoch 6
# [====================] 200/200: - running_loss: 0.6996 - running_reg: 0.000001 - running_acc: 0.5097 - lr: 0.00010 - epoch_loss: 0.6972 - epoch_reg: 0.000001 - epoch_acc: 0.5045 - valid_loss: 0.6927 - valid_reg: 0.000001 - valid_acc: 0.5080 - epoch_time: 174.3990 s
# Epoch 7
# [====================] 200/200: - running_loss: 0.6931 - running_reg: 0.000001 - running_acc: 0.5216 - lr: 0.00011 - epoch_loss: 0.6933 - epoch_reg: 0.000001 - epoch_acc: 0.5175 - valid_loss: 0.6954 - valid_reg: 0.000002 - valid_acc: 0.5001 - epoch_time: 175.2335 s
# Epoch 8
# [====================] 200/200: - running_loss: 0.6952 - running_reg: 0.000002 - running_acc: 0.5085 - lr: 0.00013 - epoch_loss: 0.6957 - epoch_reg: 0.000002 - epoch_acc: 0.5067 - valid_loss: 0.6920 - valid_reg: 0.000002 - valid_acc: 0.5262 - epoch_time: 175.3498 s
# Epoch 9
# [====================] 200/200: - running_loss: 0.6942 - running_reg: 0.000002 - running_acc: 0.5096 - lr: 0.00014 - epoch_loss: 0.6936 - epoch_reg: 0.000002 - epoch_acc: 0.5056 - valid_loss: 0.6940 - valid_reg: 0.000003 - valid_acc: 0.5146 - epoch_time: 174.6681 s
# Epoch 10
# [====================] 200/200: - running_loss: 0.6913 - running_reg: 0.000004 - running_acc: 0.5299 - lr: 0.00015 - epoch_loss: 0.6936 - epoch_reg: 0.000003 - epoch_acc: 0.5133 - valid_loss: 0.6951 - valid_reg: 0.000004 - valid_acc: 0.5219 - epoch_time: 174.7656 s
# Epoch 11
# [====================] 200/200: - running_loss: 0.6933 - running_reg: 0.000005 - running_acc: 0.5021 - lr: 0.00017 - epoch_loss: 0.6939 - epoch_reg: 0.000005 - epoch_acc: 0.5064 - valid_loss: 0.6965 - valid_reg: 0.000005 - valid_acc: 0.5001 - epoch_time: 174.6881 s
# Epoch 12
# [====================] 200/200: - running_loss: 0.6919 - running_reg: 0.000008 - running_acc: 0.5261 - lr: 0.00018 - epoch_loss: 0.6935 - epoch_reg: 0.000007 - epoch_acc: 0.5141 - valid_loss: 0.6923 - valid_reg: 0.000009 - valid_acc: 0.5225 - epoch_time: 174.8116 s
# Epoch 13
# [====================] 200/200: - running_loss: 0.6934 - running_reg: 0.000011 - running_acc: 0.5044 - lr: 0.00020 - epoch_loss: 0.6929 - epoch_reg: 0.000010 - epoch_acc: 0.5150 - valid_loss: 0.6915 - valid_reg: 0.000012 - valid_acc: 0.5355 - epoch_time: 174.9999 s
# Epoch 14
# [====================] 200/200: - running_loss: 0.6894 - running_reg: 0.000019 - running_acc: 0.5439 - lr: 0.00021 - epoch_loss: 0.6905 - epoch_reg: 0.000017 - epoch_acc: 0.5372 - valid_loss: 0.6823 - valid_reg: 0.000021 - valid_acc: 0.5570 - epoch_time: 174.8868 s
# Epoch 15
# [====================] 200/200: - running_loss: 0.6839 - running_reg: 0.000027 - running_acc: 0.5606 - lr: 0.00022 - epoch_loss: 0.6839 - epoch_reg: 0.000025 - epoch_acc: 0.5581 - valid_loss: 0.6783 - valid_reg: 0.000029 - valid_acc: 0.5731 - epoch_time: 175.0097 s
# Epoch 16
# [====================] 200/200: - running_loss: 0.6728 - running_reg: 0.000039 - running_acc: 0.5868 - lr: 0.00024 - epoch_loss: 0.6786 - epoch_reg: 0.000036 - epoch_acc: 0.5766 - valid_loss: 0.6694 - valid_reg: 0.000041 - valid_acc: 0.5885 - epoch_time: 174.8542 s
# Epoch 17
# [====================] 200/200: - running_loss: 0.6580 - running_reg: 0.000052 - running_acc: 0.6078 - lr: 0.00025 - epoch_loss: 0.6647 - epoch_reg: 0.000047 - epoch_acc: 0.5961 - valid_loss: 0.7019 - valid_reg: 0.000055 - valid_acc: 0.5453 - epoch_time: 174.8010 s
# Epoch 18
# [====================] 200/200: - running_loss: 0.6565 - running_reg: 0.000061 - running_acc: 0.6157 - lr: 0.00027 - epoch_loss: 0.6552 - epoch_reg: 0.000060 - epoch_acc: 0.6181 - valid_loss: 0.6567 - valid_reg: 0.000064 - valid_acc: 0.6168 - epoch_time: 174.9293 s
# Epoch 19
# [====================] 200/200: - running_loss: 0.6607 - running_reg: 0.000072 - running_acc: 0.6086 - lr: 0.00028 - epoch_loss: 0.6559 - epoch_reg: 0.000070 - epoch_acc: 0.6156 - valid_loss: 0.6696 - valid_reg: 0.000071 - valid_acc: 0.5805 - epoch_time: 174.7985 s
# Epoch 20
# [====================] 200/200: - running_loss: 0.6469 - running_reg: 0.000076 - running_acc: 0.6261 - lr: 0.00029 - epoch_loss: 0.6496 - epoch_reg: 0.000074 - epoch_acc: 0.6192 - valid_loss: 0.6513 - valid_reg: 0.000078 - valid_acc: 0.6204 - epoch_time: 175.0084 s
# Epoch 21
# [====================] 200/200: - running_loss: 0.6450 - running_reg: 0.000079 - running_acc: 0.6266 - lr: 0.00031 - epoch_loss: 0.6426 - epoch_reg: 0.000078 - epoch_acc: 0.6272 - valid_loss: 0.6569 - valid_reg: 0.000081 - valid_acc: 0.6128 - epoch_time: 174.7362 s
# Epoch 22
# [====================] 200/200: - running_loss: 0.6463 - running_reg: 0.000084 - running_acc: 0.6226 - lr: 0.00032 - epoch_loss: 0.6475 - epoch_reg: 0.000084 - epoch_acc: 0.6239 - valid_loss: 0.6495 - valid_reg: 0.000086 - valid_acc: 0.6261 - epoch_time: 175.0421 s
# Epoch 23
# [====================] 200/200: - running_loss: 0.6583 - running_reg: 0.000086 - running_acc: 0.6053 - lr: 0.00034 - epoch_loss: 0.6490 - epoch_reg: 0.000087 - epoch_acc: 0.6212 - valid_loss: 0.7301 - valid_reg: 0.000080 - valid_acc: 0.5062 - epoch_time: 174.8803 s
# Epoch 24
# [====================] 200/200: - running_loss: 0.6853 - running_reg: 0.000086 - running_acc: 0.5542 - lr: 0.00035 - epoch_loss: 0.6899 - epoch_reg: 0.000083 - epoch_acc: 0.5364 - valid_loss: 0.6858 - valid_reg: 0.000089 - valid_acc: 0.5337 - epoch_time: 174.8087 s
# Epoch 25
# [====================] 200/200: - running_loss: 0.6631 - running_reg: 0.000093 - running_acc: 0.6004 - lr: 0.00036 - epoch_loss: 0.6643 - epoch_reg: 0.000092 - epoch_acc: 0.5964 - valid_loss: 0.6551 - valid_reg: 0.000095 - valid_acc: 0.6137 - epoch_time: 174.8132 s
# Epoch 26
# [====================] 200/200: - running_loss: 0.6456 - running_reg: 0.000103 - running_acc: 0.6336 - lr: 0.00038 - epoch_loss: 0.6466 - epoch_reg: 0.000100 - epoch_acc: 0.6241 - valid_loss: 0.6520 - valid_reg: 0.000108 - valid_acc: 0.6172 - epoch_time: 174.8300 s
# Epoch 27
# [====================] 200/200: - running_loss: 0.6425 - running_reg: 0.000113 - running_acc: 0.6422 - lr: 0.00039 - epoch_loss: 0.6456 - epoch_reg: 0.000112 - epoch_acc: 0.6317 - valid_loss: 0.6446 - valid_reg: 0.000116 - valid_acc: 0.6311 - epoch_time: 174.9512 s
# Epoch 28
# [====================] 200/200: - running_loss: 0.6476 - running_reg: 0.000119 - running_acc: 0.6238 - lr: 0.00041 - epoch_loss: 0.6440 - epoch_reg: 0.000118 - epoch_acc: 0.6273 - valid_loss: 0.6508 - valid_reg: 0.000120 - valid_acc: 0.6268 - epoch_time: 174.8890 s
# Epoch 29
# [====================] 200/200: - running_loss: 0.6431 - running_reg: 0.000128 - running_acc: 0.6306 - lr: 0.00042 - epoch_loss: 0.6435 - epoch_reg: 0.000124 - epoch_acc: 0.6311 - valid_loss: 0.6422 - valid_reg: 0.000128 - valid_acc: 0.6328 - epoch_time: 175.0100 s
# Epoch 30
# [====================] 200/200: - running_loss: 0.6466 - running_reg: 0.000134 - running_acc: 0.6178 - lr: 0.00043 - epoch_loss: 0.6400 - epoch_reg: 0.000131 - epoch_acc: 0.6314 - valid_loss: 0.6542 - valid_reg: 0.000138 - valid_acc: 0.6052 - epoch_time: 174.8898 s
# Epoch 31
# [====================] 200/200: - running_loss: 0.6402 - running_reg: 0.000153 - running_acc: 0.6333 - lr: 0.00045 - epoch_loss: 0.6309 - epoch_reg: 0.000147 - epoch_acc: 0.6473 - valid_loss: 0.6517 - valid_reg: 0.000156 - valid_acc: 0.6264 - epoch_time: 174.9854 s
# Epoch 32
# [====================] 200/200: - running_loss: 0.6331 - running_reg: 0.000158 - running_acc: 0.6536 - lr: 0.00046 - epoch_loss: 0.6277 - epoch_reg: 0.000158 - epoch_acc: 0.6542 - valid_loss: 0.6554 - valid_reg: 0.000160 - valid_acc: 0.6234 - epoch_time: 174.9387 s
# Epoch 33
# [====================] 200/200: - running_loss: 0.6421 - running_reg: 0.000159 - running_acc: 0.6325 - lr: 0.00048 - epoch_loss: 0.6447 - epoch_reg: 0.000160 - epoch_acc: 0.6289 - valid_loss: 0.6373 - valid_reg: 0.000159 - valid_acc: 0.6431 - epoch_time: 175.1190 s
# Epoch 34
# [====================] 200/200: - running_loss: 0.6415 - running_reg: 0.000164 - running_acc: 0.6285 - lr: 0.00049 - epoch_loss: 0.6428 - epoch_reg: 0.000161 - epoch_acc: 0.6311 - valid_loss: 0.6375 - valid_reg: 0.000166 - valid_acc: 0.6381 - epoch_time: 174.9047 s
# Epoch 35
# [====================] 200/200: - running_loss: 0.6190 - running_reg: 0.000172 - running_acc: 0.6519 - lr: 0.00050 - epoch_loss: 0.6278 - epoch_reg: 0.000169 - epoch_acc: 0.6486 - valid_loss: 0.6323 - valid_reg: 0.000172 - valid_acc: 0.6465 - epoch_time: 175.1960 s
# Epoch 36
# [====================] 200/200: - running_loss: 0.6319 - running_reg: 0.000180 - running_acc: 0.6473 - lr: 0.00052 - epoch_loss: 0.6298 - epoch_reg: 0.000177 - epoch_acc: 0.6511 - valid_loss: 0.6416 - valid_reg: 0.000183 - valid_acc: 0.6414 - epoch_time: 175.0584 s
# Epoch 37
# [====================] 200/200: - running_loss: 0.6410 - running_reg: 0.000187 - running_acc: 0.6342 - lr: 0.00053 - epoch_loss: 0.6361 - epoch_reg: 0.000186 - epoch_acc: 0.6353 - valid_loss: 0.6304 - valid_reg: 0.000187 - valid_acc: 0.6480 - epoch_time: 175.2518 s
# Epoch 38
# [====================] 200/200: - running_loss: 0.6220 - running_reg: 0.000191 - running_acc: 0.6497 - lr: 0.00054 - epoch_loss: 0.6258 - epoch_reg: 0.000190 - epoch_acc: 0.6461 - valid_loss: 0.6382 - valid_reg: 0.000191 - valid_acc: 0.6457 - epoch_time: 175.0656 s
# Epoch 39
# [====================] 200/200: - running_loss: 0.6210 - running_reg: 0.000198 - running_acc: 0.6587 - lr: 0.00056 - epoch_loss: 0.6240 - epoch_reg: 0.000196 - epoch_acc: 0.6539 - valid_loss: 0.6784 - valid_reg: 0.000199 - valid_acc: 0.6241 - epoch_time: 175.0906 s
# Epoch 40
# [====================] 200/200: - running_loss: 0.6242 - running_reg: 0.000218 - running_acc: 0.6566 - lr: 0.00055 - epoch_loss: 0.6359 - epoch_reg: 0.000212 - epoch_acc: 0.6389 - valid_loss: 0.6294 - valid_reg: 0.000216 - valid_acc: 0.6509 - epoch_time: 175.2175 s
# Epoch 41
# [====================] 200/200: - running_loss: 0.6291 - running_reg: 0.000216 - running_acc: 0.6515 - lr: 0.00055 - epoch_loss: 0.6272 - epoch_reg: 0.000216 - epoch_acc: 0.6478 - valid_loss: 0.6255 - valid_reg: 0.000216 - valid_acc: 0.6539 - epoch_time: 175.2435 s
# Epoch 42
# [====================] 200/200: - running_loss: 0.6566 - running_reg: 0.000227 - running_acc: 0.6203 - lr: 0.00054 - epoch_loss: 0.6441 - epoch_reg: 0.000220 - epoch_acc: 0.6352 - valid_loss: 0.6394 - valid_reg: 0.000233 - valid_acc: 0.6463 - epoch_time: 175.0176 s
# Epoch 43
# [====================] 200/200: - running_loss: 0.6400 - running_reg: 0.000236 - running_acc: 0.6382 - lr: 0.00053 - epoch_loss: 0.6337 - epoch_reg: 0.000233 - epoch_acc: 0.6419 - valid_loss: 0.6851 - valid_reg: 0.000251 - valid_acc: 0.5057 - epoch_time: 175.0637 s
# Epoch 44
# [====================] 200/200: - running_loss: 0.6535 - running_reg: 0.000281 - running_acc: 0.6097 - lr: 0.00053 - epoch_loss: 0.6678 - epoch_reg: 0.000271 - epoch_acc: 0.5836 - valid_loss: 0.6480 - valid_reg: 0.000292 - valid_acc: 0.6276 - epoch_time: 175.1664 s
# Epoch 45
# [====================] 200/200: - running_loss: 0.6619 - running_reg: 0.000307 - running_acc: 0.6057 - lr: 0.00052 - epoch_loss: 0.6604 - epoch_reg: 0.000304 - epoch_acc: 0.6056 - valid_loss: 0.6420 - valid_reg: 0.000313 - valid_acc: 0.6380 - epoch_time: 174.9670 s
# Epoch 46
# [====================] 200/200: - running_loss: 0.6364 - running_reg: 0.000325 - running_acc: 0.6295 - lr: 0.00052 - epoch_loss: 0.6363 - epoch_reg: 0.000321 - epoch_acc: 0.6370 - valid_loss: 0.6744 - valid_reg: 0.000326 - valid_acc: 0.5509 - epoch_time: 174.9669 s
# Epoch 47
# [====================] 200/200: - running_loss: 0.6174 - running_reg: 0.000342 - running_acc: 0.6559 - lr: 0.00051 - epoch_loss: 0.6260 - epoch_reg: 0.000340 - epoch_acc: 0.6439 - valid_loss: 0.6427 - valid_reg: 0.000342 - valid_acc: 0.6359 - epoch_time: 174.8645 s
# Epoch 48
# [====================] 200/200: - running_loss: 0.6298 - running_reg: 0.000355 - running_acc: 0.6539 - lr: 0.00051 - epoch_loss: 0.6252 - epoch_reg: 0.000350 - epoch_acc: 0.6539 - valid_loss: 0.6516 - valid_reg: 0.000354 - valid_acc: 0.6389 - epoch_time: 174.9708 s
# Epoch 49
# [====================] 200/200: - running_loss: 0.6165 - running_reg: 0.000347 - running_acc: 0.6572 - lr: 0.00050 - epoch_loss: 0.6246 - epoch_reg: 0.000351 - epoch_acc: 0.6516 - valid_loss: 0.6240 - valid_reg: 0.000347 - valid_acc: 0.6607 - epoch_time: 175.3346 s
# Epoch 50
# [====================] 200/200: - running_loss: 0.6230 - running_reg: 0.000361 - running_acc: 0.6579 - lr: 0.00050 - epoch_loss: 0.6223 - epoch_reg: 0.000361 - epoch_acc: 0.6580 - valid_loss: 0.6402 - valid_reg: 0.000364 - valid_acc: 0.6364 - epoch_time: 174.8367 s
# Epoch 51
# [====================] 200/200: - running_loss: 0.6070 - running_reg: 0.000350 - running_acc: 0.6716 - lr: 0.00049 - epoch_loss: 0.6151 - epoch_reg: 0.000354 - epoch_acc: 0.6612 - valid_loss: 0.6512 - valid_reg: 0.000349 - valid_acc: 0.6458 - epoch_time: 174.7857 s
# Epoch 52
# [====================] 200/200: - running_loss: 0.6077 - running_reg: 0.000341 - running_acc: 0.6734 - lr: 0.00049 - epoch_loss: 0.6140 - epoch_reg: 0.000344 - epoch_acc: 0.6641 - valid_loss: 0.6320 - valid_reg: 0.000341 - valid_acc: 0.6544 - epoch_time: 175.0296 s
# Epoch 53
# [====================] 200/200: - running_loss: 0.6133 - running_reg: 0.000340 - running_acc: 0.6646 - lr: 0.00048 - epoch_loss: 0.6186 - epoch_reg: 0.000342 - epoch_acc: 0.6625 - valid_loss: 0.6403 - valid_reg: 0.000338 - valid_acc: 0.6507 - epoch_time: 174.8775 s
# Epoch 54
# [====================] 200/200: - running_loss: 0.6233 - running_reg: 0.000350 - running_acc: 0.6447 - lr: 0.00048 - epoch_loss: 0.6170 - epoch_reg: 0.000346 - epoch_acc: 0.6538 - valid_loss: 0.6372 - valid_reg: 0.000358 - valid_acc: 0.6417 - epoch_time: 174.7981 s
# Epoch 55
# [====================] 200/200: - running_loss: 0.6132 - running_reg: 0.000341 - running_acc: 0.6490 - lr: 0.00047 - epoch_loss: 0.6123 - epoch_reg: 0.000345 - epoch_acc: 0.6562 - valid_loss: 0.6312 - valid_reg: 0.000338 - valid_acc: 0.6451 - epoch_time: 175.0471 s
# Epoch 56
# [====================] 200/200: - running_loss: 0.6091 - running_reg: 0.000348 - running_acc: 0.6568 - lr: 0.00047 - epoch_loss: 0.6129 - epoch_reg: 0.000346 - epoch_acc: 0.6589 - valid_loss: 0.6309 - valid_reg: 0.000351 - valid_acc: 0.6631 - epoch_time: 175.1961 s
# Epoch 57
# [====================] 200/200: - running_loss: 0.5956 - running_reg: 0.000345 - running_acc: 0.6827 - lr: 0.00046 - epoch_loss: 0.5975 - epoch_reg: 0.000345 - epoch_acc: 0.6739 - valid_loss: 0.6229 - valid_reg: 0.000352 - valid_acc: 0.6595 - epoch_time: 175.0093 s
# Epoch 58
# [====================] 200/200: - running_loss: 0.6100 - running_reg: 0.000358 - running_acc: 0.6647 - lr: 0.00046 - epoch_loss: 0.6133 - epoch_reg: 0.000358 - epoch_acc: 0.6669 - valid_loss: 0.6238 - valid_reg: 0.000356 - valid_acc: 0.6603 - epoch_time: 174.9335 s
# Epoch 59
# [====================] 200/200: - running_loss: 0.6042 - running_reg: 0.000369 - running_acc: 0.6803 - lr: 0.00046 - epoch_loss: 0.6013 - epoch_reg: 0.000367 - epoch_acc: 0.6778 - valid_loss: 0.6261 - valid_reg: 0.000369 - valid_acc: 0.6552 - epoch_time: 175.0073 s
# Epoch 60
# [====================] 200/200: - running_loss: 0.5978 - running_reg: 0.000372 - running_acc: 0.6787 - lr: 0.00045 - epoch_loss: 0.6000 - epoch_reg: 0.000370 - epoch_acc: 0.6778 - valid_loss: 0.6307 - valid_reg: 0.000372 - valid_acc: 0.6587 - epoch_time: 175.1798 s
# Epoch 61
# [====================] 200/200: - running_loss: 0.6073 - running_reg: 0.000378 - running_acc: 0.6648 - lr: 0.00045 - epoch_loss: 0.6036 - epoch_reg: 0.000376 - epoch_acc: 0.6683 - valid_loss: 0.6522 - valid_reg: 0.000375 - valid_acc: 0.6323 - epoch_time: 175.0839 s
# Epoch 62
# [====================] 200/200: - running_loss: 0.5961 - running_reg: 0.000378 - running_acc: 0.6752 - lr: 0.00045 - epoch_loss: 0.6004 - epoch_reg: 0.000375 - epoch_acc: 0.6739 - valid_loss: 0.6253 - valid_reg: 0.000384 - valid_acc: 0.6488 - epoch_time: 175.0051 s
# Epoch 63
# [====================] 200/200: - running_loss: 0.6068 - running_reg: 0.000397 - running_acc: 0.6604 - lr: 0.00044 - epoch_loss: 0.6039 - epoch_reg: 0.000394 - epoch_acc: 0.6675 - valid_loss: 0.6262 - valid_reg: 0.000398 - valid_acc: 0.6548 - epoch_time: 175.0899 s
# Epoch 64
# [====================] 200/200: - running_loss: 0.5977 - running_reg: 0.000405 - running_acc: 0.6802 - lr: 0.00044 - epoch_loss: 0.5946 - epoch_reg: 0.000403 - epoch_acc: 0.6787 - valid_loss: 0.6373 - valid_reg: 0.000410 - valid_acc: 0.6381 - epoch_time: 175.0113 s
# Epoch 65
# [====================] 200/200: - running_loss: 0.5953 - running_reg: 0.000409 - running_acc: 0.6867 - lr: 0.00044 - epoch_loss: 0.5937 - epoch_reg: 0.000406 - epoch_acc: 0.6869 - valid_loss: 0.6288 - valid_reg: 0.000413 - valid_acc: 0.6571 - epoch_time: 175.1201 s
# Epoch 66
# [====================] 200/200: - running_loss: 0.5976 - running_reg: 0.000423 - running_acc: 0.6785 - lr: 0.00043 - epoch_loss: 0.5978 - epoch_reg: 0.000420 - epoch_acc: 0.6800 - valid_loss: 0.6348 - valid_reg: 0.000426 - valid_acc: 0.6510 - epoch_time: 175.1497 s
# Epoch 67
# [====================] 200/200: - running_loss: 0.5730 - running_reg: 0.000451 - running_acc: 0.6967 - lr: 0.00043 - epoch_loss: 0.5721 - epoch_reg: 0.000445 - epoch_acc: 0.7027 - valid_loss: 0.6342 - valid_reg: 0.000452 - valid_acc: 0.6544 - epoch_time: 175.2635 s
# Epoch 68
# [====================] 200/200: - running_loss: 0.5823 - running_reg: 0.000466 - running_acc: 0.6890 - lr: 0.00043 - epoch_loss: 0.5843 - epoch_reg: 0.000460 - epoch_acc: 0.6913 - valid_loss: 0.6430 - valid_reg: 0.000467 - valid_acc: 0.6497 - epoch_time: 175.4220 s
# Epoch 69
# [====================] 200/200: - running_loss: 0.5855 - running_reg: 0.000458 - running_acc: 0.6927 - lr: 0.00042 - epoch_loss: 0.5926 - epoch_reg: 0.000459 - epoch_acc: 0.6845 - valid_loss: 0.6338 - valid_reg: 0.000458 - valid_acc: 0.6528 - epoch_time: 175.2619 s
# Epoch 70
# [====================] 200/200: - running_loss: 0.5765 - running_reg: 0.000483 - running_acc: 0.6939 - lr: 0.00042 - epoch_loss: 0.5768 - epoch_reg: 0.000472 - epoch_acc: 0.6948 - valid_loss: 0.6366 - valid_reg: 0.000487 - valid_acc: 0.6478 - epoch_time: 174.9495 s
# Epoch 71
# [====================] 200/200: - running_loss: 0.5676 - running_reg: 0.000488 - running_acc: 0.7121 - lr: 0.00042 - epoch_loss: 0.5628 - epoch_reg: 0.000489 - epoch_acc: 0.7106 - valid_loss: 0.6469 - valid_reg: 0.000487 - valid_acc: 0.6458 - epoch_time: 175.1128 s
# Epoch 72
# [====================] 200/200: - running_loss: 0.5559 - running_reg: 0.000497 - running_acc: 0.7216 - lr: 0.00041 - epoch_loss: 0.5596 - epoch_reg: 0.000494 - epoch_acc: 0.7166 - valid_loss: 0.6508 - valid_reg: 0.000502 - valid_acc: 0.6474 - epoch_time: 175.1259 s
# Epoch 73
# ...
# Epoch 68
# [====================] 200/200: - running_loss: 0.5694 - running_reg: 0.000224 - running_acc: 0.6986 - lr: 0.00043 - epoch_loss: 0.5746 - epoch_reg: 0.000223 - epoch_acc: 0.6981 - valid_loss: 0.6390 - valid_reg: 0.000226 - valid_acc: 0.6508 - epoch_time: 174.7791 s
# Epoch 69
# [====================] 200/200: - running_loss: 0.5759 - running_reg: 0.000224 - running_acc: 0.6944 - lr: 0.00042 - epoch_loss: 0.5775 - epoch_reg: 0.000224 - epoch_acc: 0.6928 - valid_loss: 0.6446 - valid_reg: 0.000225 - valid_acc: 0.6509 - epoch_time: 174.7859 s
# Epoch 70
# [====================] 200/200: - running_loss: 0.5440 - running_reg: 0.000226 - running_acc: 0.7269 - lr: 0.00042 - epoch_loss: 0.5562 - epoch_reg: 0.000225 - epoch_acc: 0.7150 - valid_loss: 0.6635 - valid_reg: 0.000227 - valid_acc: 0.6503 - epoch_time: 174.8159 s
# Epoch 71
# [====================] 200/200: - running_loss: 0.5598 - running_reg: 0.000235 - running_acc: 0.7157 - lr: 0.00042 - epoch_loss: 0.5593 - epoch_reg: 0.000232 - epoch_acc: 0.7184 - valid_loss: 0.6536 - valid_reg: 0.000237 - valid_acc: 0.6480 - epoch_time: 174.8209 s
# Epoch 72
# [====================] 200/200: - running_loss: 0.5696 - running_reg: 0.000241 - running_acc: 0.7102 - lr: 0.00041 - epoch_loss: 0.5712 - epoch_reg: 0.000239 - epoch_acc: 0.7088 - valid_loss: 0.6356 - valid_reg: 0.000242 - valid_acc: 0.6452 - epoch_time: 174.6982 s
# Epoch 73
# [====================] 200/200: - running_loss: 0.5740 - running_reg: 0.000244 - running_acc: 0.7045 - lr: 0.00041 - epoch_loss: 0.5650 - epoch_reg: 0.000244 - epoch_acc: 0.7109 - valid_loss: 0.6320 - valid_reg: 0.000243 - valid_acc: 0.6459 - epoch_time: 174.9956 s
# Epoch 74
# [====================] 200/200: - running_loss: 0.5584 - running_reg: 0.000251 - running_acc: 0.7139 - lr: 0.00041 - epoch_loss: 0.5601 - epoch_reg: 0.000248 - epoch_acc: 0.7134 - valid_loss: 0.6430 - valid_reg: 0.000252 - valid_acc: 0.6401 - epoch_time: 174.7645 s
# Epoch 75
# [====================] 200/200: - running_loss: 0.5647 - running_reg: 0.000253 - running_acc: 0.7132 - lr: 0.00041 - epoch_loss: 0.5552 - epoch_reg: 0.000253 - epoch_acc: 0.7183 - valid_loss: 0.6472 - valid_reg: 0.000253 - valid_acc: 0.6455 - epoch_time: 174.9375 s
# Epoch 76
# [====================] 200/200: - running_loss: 0.5475 - running_reg: 0.000257 - running_acc: 0.7310 - lr: 0.00040 - epoch_loss: 0.5438 - epoch_reg: 0.000256 - epoch_acc: 0.7319 - valid_loss: 0.6649 - valid_reg: 0.000256 - valid_acc: 0.6400 - epoch_time: 174.8057 s
# Epoch 77
# [====================] 200/200: - running_loss: 0.5701 - running_reg: 0.000265 - running_acc: 0.7135 - lr: 0.00040 - epoch_loss: 0.5608 - epoch_reg: 0.000260 - epoch_acc: 0.7170 - valid_loss: 0.6467 - valid_reg: 0.000287 - valid_acc: 0.6246 - epoch_time: 174.8071 s
# Epoch 78
# [====================] 200/200: - running_loss: 0.5362 - running_reg: 0.000302 - running_acc: 0.7374 - lr: 0.00040 - epoch_loss: 0.5425 - epoch_reg: 0.000308 - epoch_acc: 0.7327 - valid_loss: 0.6698 - valid_reg: 0.000298 - valid_acc: 0.6403 - epoch_time: 174.9093 s
# Epoch 79
# [====================] 200/200: - running_loss: 0.5479 - running_reg: 0.000292 - running_acc: 0.7251 - lr: 0.00040 - epoch_loss: 0.5448 - epoch_reg: 0.000294 - epoch_acc: 0.7236 - valid_loss: 0.6660 - valid_reg: 0.000291 - valid_acc: 0.6400 - epoch_time: 174.8093 s
# Epoch 80
# [====================] 200/200: - running_loss: 0.5483 - running_reg: 0.000287 - running_acc: 0.7253 - lr: 0.00039 - epoch_loss: 0.5417 - epoch_reg: 0.000288 - epoch_acc: 0.7291 - valid_loss: 0.6543 - valid_reg: 0.000286 - valid_acc: 0.6379 - epoch_time: 174.7935 s
# Epoch 81
# [====================] 200/200: - running_loss: 0.5394 - running_reg: 0.000297 - running_acc: 0.7304 - lr: 0.00039 - epoch_loss: 0.5353 - epoch_reg: 0.000295 - epoch_acc: 0.7366 - valid_loss: 0.6704 - valid_reg: 0.000296 - valid_acc: 0.6391 - epoch_time: 174.8481 s
# Epoch 82
# [====================] 200/200: - running_loss: 0.5355 - running_reg: 0.000299 - running_acc: 0.7339 - lr: 0.00039 - epoch_loss: 0.5225 - epoch_reg: 0.000298 - epoch_acc: 0.7430 - valid_loss: 0.6581 - valid_reg: 0.000299 - valid_acc: 0.6372 - epoch_time: 174.6723 s
# Epoch 83
# [====================] 200/200: - running_loss: 0.5277 - running_reg: 0.000303 - running_acc: 0.7373 - lr: 0.00039 - epoch_loss: 0.5262 - epoch_reg: 0.000301 - epoch_acc: 0.7378 - valid_loss: 0.6987 - valid_reg: 0.000305 - valid_acc: 0.6370 - epoch_time: 174.7544 s
# Epoch 84
# [====================] 200/200: - running_loss: 0.5135 - running_reg: 0.000303 - running_acc: 0.7525 - lr: 0.00038 - epoch_loss: 0.5245 - epoch_reg: 0.000303 - epoch_acc: 0.7466 - valid_loss: 0.6895 - valid_reg: 0.000302 - valid_acc: 0.6380 - epoch_time: 174.8639 s
# Epoch 85
# [====================] 200/200: - running_loss: 0.5221 - running_reg: 0.000301 - running_acc: 0.7442 - lr: 0.00038 - epoch_loss: 0.5356 - epoch_reg: 0.000301 - epoch_acc: 0.7330 - valid_loss: 0.6820 - valid_reg: 0.000303 - valid_acc: 0.6380 - epoch_time: 174.9778 s
# Epoch 86
# [====================] 200/200: - running_loss: 0.5050 - running_reg: 0.000311 - running_acc: 0.7576 - lr: 0.00038 - epoch_loss: 0.5010 - epoch_reg: 0.000308 - epoch_acc: 0.7592 - valid_loss: 0.6943 - valid_reg: 0.000311 - valid_acc: 0.6277 - epoch_time: 174.9973 s
# Epoch 87
# [====================] 200/200: - running_loss: 0.5134 - running_reg: 0.000318 - running_acc: 0.7507 - lr: 0.00038 - epoch_loss: 0.5131 - epoch_reg: 0.000316 - epoch_acc: 0.7491 - valid_loss: 0.6924 - valid_reg: 0.000320 - valid_acc: 0.6311 - epoch_time: 174.8745 s
# Epoch 88
# [====================] 200/200: - running_loss: 0.5175 - running_reg: 0.000324 - running_acc: 0.7564 - lr: 0.00037 - epoch_loss: 0.5191 - epoch_reg: 0.000323 - epoch_acc: 0.7552 - valid_loss: 0.6996 - valid_reg: 0.000322 - valid_acc: 0.6335 - epoch_time: 174.9416 s
# Epoch 89
# [====================] 200/200: - running_loss: 0.5169 - running_reg: 0.000323 - running_acc: 0.7486 - lr: 0.00037 - epoch_loss: 0.5178 - epoch_reg: 0.000323 - epoch_acc: 0.7445 - valid_loss: 0.6818 - valid_reg: 0.000324 - valid_acc: 0.6338 - epoch_time: 175.0030 s
# Epoch 90
# [====================] 200/200: - running_loss: 0.4863 - running_reg: 0.000334 - running_acc: 0.7702 - lr: 0.00037 - epoch_loss: 0.4917 - epoch_reg: 0.000331 - epoch_acc: 0.7683 - valid_loss: 0.7392 - valid_reg: 0.000334 - valid_acc: 0.6367 - epoch_time: 174.8517 s
# Epoch 91
# [====================] 200/200: - running_loss: 0.4866 - running_reg: 0.000336 - running_acc: 0.7678 - lr: 0.00037 - epoch_loss: 0.4840 - epoch_reg: 0.000335 - epoch_acc: 0.7700 - valid_loss: 0.7255 - valid_reg: 0.000337 - valid_acc: 0.6289 - epoch_time: 174.9325 s
# Epoch 92
# [====================] 200/200: - running_loss: 0.5013 - running_reg: 0.000342 - running_acc: 0.7597 - lr: 0.00037 - epoch_loss: 0.5022 - epoch_reg: 0.000340 - epoch_acc: 0.7575 - valid_loss: 0.6936 - valid_reg: 0.000341 - valid_acc: 0.6266 - epoch_time: 174.8693 s
# Epoch 93
# [====================] 200/200: - running_loss: 0.4959 - running_reg: 0.000345 - running_acc: 0.7526 - lr: 0.00036 - epoch_loss: 0.5127 - epoch_reg: 0.000344 - epoch_acc: 0.7408 - valid_loss: 0.7602 - valid_reg: 0.000350 - valid_acc: 0.6159 - epoch_time: 175.1379 s
# Epoch 94
# [====================] 200/200: - running_loss: 0.4944 - running_reg: 0.000353 - running_acc: 0.7605 - lr: 0.00036 - epoch_loss: 0.4940 - epoch_reg: 0.000352 - epoch_acc: 0.7627 - valid_loss: 0.7031 - valid_reg: 0.000352 - valid_acc: 0.6228 - epoch_time: 175.3547 s
# Epoch 95
# [====================] 200/200: - running_loss: 0.5087 - running_reg: 0.000357 - running_acc: 0.7548 - lr: 0.00036 - epoch_loss: 0.4963 - epoch_reg: 0.000355 - epoch_acc: 0.7595 - valid_loss: 0.7049 - valid_reg: 0.000362 - valid_acc: 0.6287 - epoch_time: 175.0568 s
# Epoch 96
# [====================] 200/200: - running_loss: 0.4908 - running_reg: 0.000361 - running_acc: 0.7592 - lr: 0.00036 - epoch_loss: 0.4908 - epoch_reg: 0.000362 - epoch_acc: 0.7616 - valid_loss: 0.6877 - valid_reg: 0.000359 - valid_acc: 0.6295 - epoch_time: 175.1687 s
# Epoch 97
# [====================] 200/200: - running_loss: 0.4838 - running_reg: 0.000364 - running_acc: 0.7673 - lr: 0.00036 - epoch_loss: 0.4985 - epoch_reg: 0.000362 - epoch_acc: 0.7594 - valid_loss: 0.7542 - valid_reg: 0.000367 - valid_acc: 0.6246 - epoch_time: 173.8044 s
# Epoch 98
# [====================] 200/200: - running_loss: 0.4857 - running_reg: 0.000378 - running_acc: 0.7746 - lr: 0.00036 - epoch_loss: 0.4824 - epoch_reg: 0.000376 - epoch_acc: 0.7741 - valid_loss: 0.7767 - valid_reg: 0.000377 - valid_acc: 0.6240 - epoch_time: 171.3179 s
# Epoch 99
# [====================] 200/200: - running_loss: 0.4669 - running_reg: 0.000379 - running_acc: 0.7785 - lr: 0.00035 - epoch_loss: 0.4743 - epoch_reg: 0.000379 - epoch_acc: 0.7747 - valid_loss: 0.7674 - valid_reg: 0.000378 - valid_acc: 0.6286 - epoch_time: 171.3714 s
#  - test_loss: 0.6207 - test_reg: 0.000162 - test_acc: 0.6617 - test_time: 94.3257 s
# Original model 3464194 params, new model 3792898 params, ratio 1.09
# Epoch 0
# [====================] 200/200: - running_loss: 0.6978 - running_reg: 0.000000 - running_acc: 0.5036 - lr: 0.00001 - epoch_loss: 0.6963 - epoch_reg: 0.000000 - epoch_acc: 0.5083 - valid_loss: 0.6922 - valid_reg: 0.000000 - valid_acc: 0.5224 - epoch_time: 186.3601 s
# Epoch 1
# [====================] 200/200: - running_loss: 0.6946 - running_reg: 0.000000 - running_acc: 0.5151 - lr: 0.00003 - epoch_loss: 0.6962 - epoch_reg: 0.000000 - epoch_acc: 0.5063 - valid_loss: 0.6938 - valid_reg: 0.000000 - valid_acc: 0.5001 - epoch_time: 178.5812 s
# Epoch 2
# [====================] 200/200: - running_loss: 0.6942 - running_reg: 0.000000 - running_acc: 0.5004 - lr: 0.00004 - epoch_loss: 0.6947 - epoch_reg: 0.000000 - epoch_acc: 0.5005 - valid_loss: 0.6924 - valid_reg: 0.000000 - valid_acc: 0.5178 - epoch_time: 176.6927 s
# Epoch 3
# [====================] 200/200: - running_loss: 0.6955 - running_reg: 0.000000 - running_acc: 0.5099 - lr: 0.00006 - epoch_loss: 0.6961 - epoch_reg: 0.000000 - epoch_acc: 0.5091 - valid_loss: 0.6976 - valid_reg: 0.000000 - valid_acc: 0.5044 - epoch_time: 174.2764 s
# Epoch 4
# [====================] 200/200: - running_loss: 0.7040 - running_reg: 0.000000 - running_acc: 0.4985 - lr: 0.00007 - epoch_loss: 0.6978 - epoch_reg: 0.000000 - epoch_acc: 0.4972 - valid_loss: 0.7143 - valid_reg: 0.000000 - valid_acc: 0.4999 - epoch_time: 175.0412 s
# Epoch 5
# [====================] 200/200: - running_loss: 0.6967 - running_reg: 0.000000 - running_acc: 0.5051 - lr: 0.00008 - epoch_loss: 0.6954 - epoch_reg: 0.000000 - epoch_acc: 0.5077 - valid_loss: 0.6963 - valid_reg: 0.000000 - valid_acc: 0.5001 - epoch_time: 174.4246 s
# Epoch 6
# [====================] 200/200: - running_loss: 0.6958 - running_reg: 0.000001 - running_acc: 0.5191 - lr: 0.00010 - epoch_loss: 0.6951 - epoch_reg: 0.000001 - epoch_acc: 0.5158 - valid_loss: 0.6964 - valid_reg: 0.000001 - valid_acc: 0.5034 - epoch_time: 174.6079 s
# Epoch 7
# [====================] 200/200: - running_loss: 0.6940 - running_reg: 0.000001 - running_acc: 0.5073 - lr: 0.00011 - epoch_loss: 0.6946 - epoch_reg: 0.000001 - epoch_acc: 0.5072 - valid_loss: 0.6953 - valid_reg: 0.000001 - valid_acc: 0.5052 - epoch_time: 174.5398 s
# Epoch 8
# [====================] 200/200: - running_loss: 0.6966 - running_reg: 0.000002 - running_acc: 0.4989 - lr: 0.00013 - epoch_loss: 0.6963 - epoch_reg: 0.000002 - epoch_acc: 0.5019 - valid_loss: 0.6923 - valid_reg: 0.000002 - valid_acc: 0.5166 - epoch_time: 175.1088 s
# Epoch 9
# [====================] 200/200: - running_loss: 0.6937 - running_reg: 0.000004 - running_acc: 0.5192 - lr: 0.00014 - epoch_loss: 0.6940 - epoch_reg: 0.000003 - epoch_acc: 0.5181 - valid_loss: 0.6942 - valid_reg: 0.000004 - valid_acc: 0.5085 - epoch_time: 174.7046 s
# Epoch 10
# [====================] 200/200: - running_loss: 0.6936 - running_reg: 0.000004 - running_acc: 0.5220 - lr: 0.00015 - epoch_loss: 0.6944 - epoch_reg: 0.000004 - epoch_acc: 0.5109 - valid_loss: 0.6941 - valid_reg: 0.000005 - valid_acc: 0.5169 - epoch_time: 174.9094 s
# Epoch 11
# [====================] 200/200: - running_loss: 0.6935 - running_reg: 0.000007 - running_acc: 0.5187 - lr: 0.00017 - epoch_loss: 0.6944 - epoch_reg: 0.000006 - epoch_acc: 0.5100 - valid_loss: 0.6964 - valid_reg: 0.000008 - valid_acc: 0.5001 - epoch_time: 174.8609 s
# Epoch 12
# [====================] 200/200: - running_loss: 0.6921 - running_reg: 0.000006 - running_acc: 0.5305 - lr: 0.00018 - epoch_loss: 0.6934 - epoch_reg: 0.000006 - epoch_acc: 0.5263 - valid_loss: 0.6931 - valid_reg: 0.000006 - valid_acc: 0.5171 - epoch_time: 174.9618 s
# Epoch 13
# [====================] 200/200: - running_loss: 0.6946 - running_reg: 0.000008 - running_acc: 0.5058 - lr: 0.00020 - epoch_loss: 0.6928 - epoch_reg: 0.000007 - epoch_acc: 0.5153 - valid_loss: 0.6931 - valid_reg: 0.000008 - valid_acc: 0.5044 - epoch_time: 175.0495 s
# Epoch 14
# [====================] 200/200: - running_loss: 0.6926 - running_reg: 0.000011 - running_acc: 0.5313 - lr: 0.00021 - epoch_loss: 0.6931 - epoch_reg: 0.000010 - epoch_acc: 0.5173 - valid_loss: 0.6921 - valid_reg: 0.000011 - valid_acc: 0.5238 - epoch_time: 174.9785 s
# Epoch 15
# [====================] 200/200: - running_loss: 0.6902 - running_reg: 0.000012 - running_acc: 0.5415 - lr: 0.00022 - epoch_loss: 0.6915 - epoch_reg: 0.000012 - epoch_acc: 0.5275 - valid_loss: 0.6903 - valid_reg: 0.000014 - valid_acc: 0.5288 - epoch_time: 175.1033 s
# Epoch 16
# [====================] 200/200: - running_loss: 0.6877 - running_reg: 0.000020 - running_acc: 0.5581 - lr: 0.00024 - epoch_loss: 0.6896 - epoch_reg: 0.000018 - epoch_acc: 0.5444 - valid_loss: 0.6828 - valid_reg: 0.000021 - valid_acc: 0.5615 - epoch_time: 175.0376 s
# Epoch 17
# [====================] 200/200: - running_loss: 0.6906 - running_reg: 0.000020 - running_acc: 0.5321 - lr: 0.00025 - epoch_loss: 0.6935 - epoch_reg: 0.000020 - epoch_acc: 0.5200 - valid_loss: 0.6864 - valid_reg: 0.000021 - valid_acc: 0.5558 - epoch_time: 175.0174 s
# Epoch 18
# [====================] 200/200: - running_loss: 0.6830 - running_reg: 0.000031 - running_acc: 0.5692 - lr: 0.00027 - epoch_loss: 0.6841 - epoch_reg: 0.000028 - epoch_acc: 0.5658 - valid_loss: 0.6853 - valid_reg: 0.000033 - valid_acc: 0.5647 - epoch_time: 175.0821 s
# Epoch 19
# [====================] 200/200: - running_loss: 0.6828 - running_reg: 0.000036 - running_acc: 0.5589 - lr: 0.00028 - epoch_loss: 0.6829 - epoch_reg: 0.000035 - epoch_acc: 0.5581 - valid_loss: 0.6828 - valid_reg: 0.000036 - valid_acc: 0.5814 - epoch_time: 174.9633 s
# Epoch 20
# [====================] 200/200: - running_loss: 0.6742 - running_reg: 0.000039 - running_acc: 0.5831 - lr: 0.00029 - epoch_loss: 0.6770 - epoch_reg: 0.000038 - epoch_acc: 0.5791 - valid_loss: 0.6804 - valid_reg: 0.000040 - valid_acc: 0.5638 - epoch_time: 174.8035 s
# Epoch 21
# [====================] 200/200: - running_loss: 0.6743 - running_reg: 0.000043 - running_acc: 0.5819 - lr: 0.00031 - epoch_loss: 0.6747 - epoch_reg: 0.000042 - epoch_acc: 0.5825 - valid_loss: 0.6750 - valid_reg: 0.000045 - valid_acc: 0.5712 - epoch_time: 175.0330 s
# Epoch 22
# [====================] 200/200: - running_loss: 0.6542 - running_reg: 0.000048 - running_acc: 0.6186 - lr: 0.00032 - epoch_loss: 0.6638 - epoch_reg: 0.000047 - epoch_acc: 0.5984 - valid_loss: 0.6691 - valid_reg: 0.000049 - valid_acc: 0.5967 - epoch_time: 175.0974 s
# Epoch 23
# [====================] 200/200: - running_loss: 0.6635 - running_reg: 0.000055 - running_acc: 0.5970 - lr: 0.00034 - epoch_loss: 0.6668 - epoch_reg: 0.000054 - epoch_acc: 0.5942 - valid_loss: 0.6808 - valid_reg: 0.000057 - valid_acc: 0.5969 - epoch_time: 175.0685 s
# Epoch 24
# [====================] 200/200: - running_loss: 0.6660 - running_reg: 0.000061 - running_acc: 0.6015 - lr: 0.00035 - epoch_loss: 0.6613 - epoch_reg: 0.000059 - epoch_acc: 0.6134 - valid_loss: 0.6652 - valid_reg: 0.000062 - valid_acc: 0.5966 - epoch_time: 174.9987 s
# Epoch 25
# [=============>------] 144/200: - running_loss: 0.6529 - running_reg: 0.000071 - running_acc: 0.6273 - lr: 0.00036

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output[0].detach()
    return hook

process_inputs = lambda x: torch.Tensor(x.numpy()).to(torch.int64)

list(model.blocks[-1].attention.lka.modules())[0][0].register_forward_hook(get_activation('1'))
#list(model.blocks[-1].attention.lka.modules())[0][1].register_forward_hook(get_activation('2'))

# %%
model(process_inputs(next(iter(train_dataset))['inputs']).cuda())
activation
# Out:
# {'1': tensor([[[[0.4846, 0.6129, 1.0817,  ..., 0.8458, 0.8182, 0.6113],
#            [0.6741, 1.0226, 0.9306,  ..., 0.6382, 0.4864, 0.4956],
#            [0.7144, 0.7925, 0.9776,  ..., 0.8392, 0.8342, 0.6923],
#            ...,
#            [0.6351, 0.4956, 0.8323,  ..., 1.1306, 0.8587, 0.7959],
#            [0.6259, 1.0617, 0.9905,  ..., 0.7249, 0.8088, 0.8153],
#            [0.7734, 0.8578, 0.5455,  ..., 0.5648, 0.7239, 0.6971]],
#
#           [[1.1219, 0.8068, 0.7288,  ..., 0.5271, 1.1042, 0.6128],
#            [0.8955, 0.9000, 1.3224,  ..., 0.5096, 0.5674, 1.1289],
#            [0.7283, 0.8557, 0.4822,  ..., 0.8176, 0.3683, 0.6196],
#            ...,
#            [0.6962, 0.6160, 0.4413,  ..., 1.0298, 0.8417, 0.8641],
#            [1.0189, 0.9670, 0.5587,  ..., 0.9078, 0.7291, 0.7901],
#            [0.6431, 0.5184, 0.5831,  ..., 0.6299, 0.6459, 0.6050]],
#
#           [[0.6520, 0.8644, 0.8144,  ..., 0.5583, 0.4932, 0.5764],
#            [0.3789, 0.7886, 0.5084,  ..., 0.7604, 0.5583, 0.4504],
#            [0.8306, 0.9530, 0.6154,  ..., 0.7198, 0.6716, 0.8316],
#            ...,
#            [0.7072, 0.7885, 0.6645,  ..., 0.5373, 0.8313, 0.7544],
#            [0.9306, 0.6810, 0.7918,  ..., 0.8676, 0.8027, 0.7283],
#            [0.6329, 0.6154, 0.7098,  ..., 0.4776, 0.7722, 0.6611]],
#
#           [[0.7786, 0.9671, 0.7944,  ..., 0.6249, 0.8022, 0.5712],
#            [0.5801, 0.6983, 0.5575,  ..., 0.6784, 0.7260, 0.7423],
#            [0.7165, 0.7591, 0.9826,  ..., 0.4811, 0.4956, 0.8089],
#            ...,
#            [0.9886, 0.6557, 0.4287,  ..., 1.0515, 0.5590, 1.2194],
#            [0.8846, 0.6401, 0.7460,  ..., 0.5371, 0.7053, 0.6377],
#            [0.9957, 0.2716, 0.6007,  ..., 0.9580, 0.3327, 0.6476]]],
#
#
#          [[[0.8930, 0.6364, 0.6370,  ..., 0.6555, 0.5743, 0.8378],
#            [0.8831, 0.9794, 0.8412,  ..., 0.5675, 0.6064, 0.7537],
#            [0.8718, 0.6853, 0.8128,  ..., 0.8434, 0.6892, 0.5453],
#            ...,
#            [0.7026, 0.5422, 0.3716,  ..., 0.4875, 0.7247, 0.8934],
#            [1.2645, 0.7219, 0.6805,  ..., 0.7243, 1.0154, 0.7983],
#            [0.5913, 0.8728, 0.8055,  ..., 0.9002, 0.7161, 0.8851]],
#
#           [[0.4333, 0.6424, 0.4917,  ..., 0.6138, 0.8224, 1.0296],
#            [0.5902, 1.0217, 0.7909,  ..., 0.6172, 0.5229, 0.6886],
#            [0.9553, 0.6320, 0.3309,  ..., 1.1288, 0.4941, 0.7927],
#            ...,
#            [0.5305, 0.5709, 1.0517,  ..., 0.5401, 0.4635, 1.2611],
#            [0.5408, 0.6843, 1.0863,  ..., 0.7544, 0.3629, 0.8321],
#            [0.7382, 0.7683, 0.7612,  ..., 0.7868, 0.5918, 0.5935]],
#
#           [[0.7341, 0.9329, 1.0449,  ..., 0.8102, 1.0817, 0.8769],
#            [0.6250, 0.6260, 0.9342,  ..., 0.7469, 0.5003, 0.5282],
#            [0.6004, 0.5281, 1.0101,  ..., 0.8523, 0.6920, 0.7553],
#            ...,
#            [0.9517, 0.9641, 0.9220,  ..., 0.4221, 0.4426, 0.8048],
#            [0.4548, 0.5333, 0.5736,  ..., 1.1812, 0.5742, 0.6966],
#            [0.7830, 0.4640, 0.5448,  ..., 0.6196, 0.5784, 0.7986]],
#
#           [[0.7263, 0.8433, 0.6435,  ..., 0.6081, 0.9357, 1.0626],
#            [0.3649, 0.7983, 0.5728,  ..., 0.4686, 0.9862, 0.7960],
#            [0.6301, 0.7797, 0.4217,  ..., 0.6837, 0.6317, 0.9112],
#            ...,
#            [0.5928, 0.6314, 0.7262,  ..., 0.6301, 0.5901, 1.0862],
#            [0.5278, 0.4373, 0.4281,  ..., 0.7741, 0.5059, 1.1810],
#            [0.5299, 0.4793, 0.6697,  ..., 0.5519, 0.4068, 0.5940]]],
#
#
#          [[[0.5173, 0.4609, 0.3646,  ..., 0.7049, 0.8529, 1.0608],
#            [0.8809, 0.4967, 0.6903,  ..., 0.6765, 0.4130, 0.8474],
#            [0.4907, 0.7993, 0.4250,  ..., 0.7400, 0.7169, 0.8319],
#            ...,
#            [0.7427, 0.6648, 0.7337,  ..., 0.6867, 0.7303, 0.6022],
#            [0.9273, 0.7987, 1.1405,  ..., 0.6633, 0.4618, 0.4035],
#            [0.7829, 0.7052, 0.7513,  ..., 0.7967, 0.3077, 0.5792]],
#
#           [[0.5744, 0.5170, 0.5111,  ..., 0.6387, 1.4359, 0.6881],
#            [0.5406, 0.7437, 0.6796,  ..., 0.6085, 0.3997, 0.6651],
#            [0.9269, 0.7365, 0.6759,  ..., 0.4442, 0.9492, 0.7859],
#            ...,
#            [0.5625, 1.0477, 0.6989,  ..., 0.3193, 0.9648, 0.9948],
#            [0.8559, 0.5630, 0.6819,  ..., 0.7938, 1.0081, 0.7846],
#            [0.7721, 0.6051, 0.9171,  ..., 0.8199, 0.5124, 0.6793]],
#
#           [[0.5939, 0.7135, 0.6993,  ..., 0.8693, 0.7109, 0.4790],
#            [1.2267, 0.5138, 0.8688,  ..., 0.6919, 0.4456, 1.1771],
#            [0.8001, 0.5119, 0.4499,  ..., 0.7845, 1.0466, 0.6150],
#            ...,
#            [0.9662, 0.5447, 0.5725,  ..., 0.7900, 0.4642, 0.8714],
#            [0.6128, 1.4435, 1.0496,  ..., 0.4937, 0.8764, 0.7703],
#            [1.1477, 0.4474, 1.1052,  ..., 0.4511, 0.7057, 1.1471]],
#
#           [[0.5751, 0.7363, 0.5543,  ..., 1.2802, 1.0292, 0.9101],
#            [0.8339, 0.7821, 0.4958,  ..., 0.6689, 0.7094, 1.2240],
#            [0.6334, 0.6162, 1.0532,  ..., 0.5831, 0.9784, 0.4457],
#            ...,
#            [0.9673, 0.5089, 0.5119,  ..., 0.7646, 0.6643, 0.6362],
#            [0.6229, 0.8128, 0.6808,  ..., 0.8241, 0.7474, 0.5344],
#            [0.5732, 0.8781, 0.8293,  ..., 0.5295, 0.3167, 0.6894]]],
#
#
#          ...,
#
#
#          [[[0.5139, 0.9585, 0.7048,  ..., 0.4706, 1.1845, 0.8306],
#            [0.6485, 0.6921, 0.7455,  ..., 0.8412, 0.9490, 0.7054],
#            [0.8574, 0.5853, 0.8126,  ..., 0.8271, 0.9612, 0.7024],
#            ...,
#            [0.8571, 0.9179, 1.1562,  ..., 1.0475, 0.6699, 0.6514],
#            [0.5395, 0.8354, 0.7111,  ..., 0.8484, 0.9584, 0.6190],
#            [0.8390, 0.5624, 0.5619,  ..., 0.7656, 0.6843, 0.4733]],
#
#           [[1.1947, 0.8580, 0.8976,  ..., 0.7886, 0.7540, 0.7705],
#            [0.8955, 0.8698, 0.7398,  ..., 0.6024, 0.6055, 0.7405],
#            [0.5969, 0.4527, 0.7469,  ..., 0.5325, 0.7581, 0.8009],
#            ...,
#            [0.6167, 0.6102, 0.5931,  ..., 0.9055, 1.1287, 0.8764],
#            [0.8777, 0.9808, 0.7232,  ..., 0.9431, 0.2721, 0.6570],
#            [0.5581, 0.4597, 0.7226,  ..., 0.7046, 0.5034, 0.6325]],
#
#           [[0.6878, 0.8854, 0.5886,  ..., 0.6195, 0.8855, 0.6604],
#            [0.7996, 0.5236, 0.8830,  ..., 0.6311, 0.6650, 0.7740],
#            [0.5857, 0.6802, 0.6618,  ..., 0.4279, 0.5291, 0.7272],
#            ...,
#            [0.6958, 0.6722, 0.4040,  ..., 0.7566, 0.5490, 0.2878],
#            [0.6755, 0.7320, 0.6415,  ..., 0.5381, 0.8886, 1.0171],
#            [0.7361, 0.7721, 0.8607,  ..., 0.8243, 0.6769, 0.7289]],
#
#           [[0.5134, 1.0933, 0.5616,  ..., 0.5353, 0.6832, 0.6531],
#            [0.7765, 0.6428, 0.7305,  ..., 0.3585, 0.7072, 0.5546],
#            [0.8771, 0.5484, 0.7344,  ..., 0.6258, 0.7448, 0.3164],
#            ...,
#            [0.6185, 0.7809, 1.2525,  ..., 0.9899, 0.4716, 0.6864],
#            [0.8044, 0.7140, 0.3929,  ..., 0.5716, 0.2625, 0.5923],
#            [0.7273, 0.9700, 0.7583,  ..., 0.4546, 0.6063, 0.9399]]],
#
#
#          [[[0.4228, 0.8486, 0.9001,  ..., 0.6750, 0.6145, 0.3459],
#            [0.9708, 0.7545, 0.9327,  ..., 0.6346, 0.7672, 0.7432],
#            [0.7026, 0.8030, 0.7853,  ..., 0.5845, 0.6818, 0.5152],
#            ...,
#            [0.8206, 0.4788, 1.2461,  ..., 0.7114, 0.4759, 0.6254],
#            [0.6418, 0.6923, 0.8943,  ..., 0.7203, 0.6995, 0.7107],
#            [0.6397, 0.5745, 1.0160,  ..., 0.8132, 0.7279, 0.5532]],
#
#           [[0.7658, 0.6374, 0.7984,  ..., 0.7095, 0.7758, 0.7840],
#            [0.7832, 0.4628, 0.3681,  ..., 0.7452, 0.7778, 0.7669],
#            [0.7413, 0.6951, 0.5761,  ..., 1.0948, 0.4968, 0.4787],
#            ...,
#            [0.9395, 1.0545, 0.6344,  ..., 0.7220, 0.4989, 0.7187],
#            [0.7035, 0.8188, 0.5433,  ..., 0.7804, 0.5496, 0.5223],
#            [0.8402, 0.7453, 0.3474,  ..., 0.6197, 0.7948, 0.6134]],
#
#           [[0.3603, 1.1036, 0.5891,  ..., 0.8252, 0.4258, 0.3955],
#            [0.7111, 0.9473, 0.4409,  ..., 0.8261, 0.5765, 0.4974],
#            [0.6300, 0.8217, 1.0144,  ..., 0.9546, 1.1750, 1.1056],
#            ...,
#            [0.8961, 0.4505, 0.7297,  ..., 0.8524, 0.4372, 1.0410],
#            [0.7747, 0.5040, 0.6784,  ..., 0.5566, 1.1498, 0.7962],
#            [0.6596, 1.1634, 0.4957,  ..., 0.7880, 0.5380, 0.6310]],
#
#           [[0.5279, 0.7320, 0.9941,  ..., 0.8691, 1.0518, 0.7016],
#            [0.7898, 0.6883, 0.5457,  ..., 0.3695, 0.5490, 0.7430],
#            [0.5119, 0.8078, 0.5855,  ..., 0.5621, 0.9829, 0.7496],
#            ...,
#            [0.5684, 1.1142, 0.7967,  ..., 0.5090, 0.4609, 0.7501],
#            [0.4333, 0.6514, 0.8165,  ..., 0.9520, 0.8970, 1.1366],
#            [0.4308, 0.3284, 0.8361,  ..., 0.8206, 1.0035, 0.4980]]],
#
#
#          [[[0.7467, 0.6446, 0.5154,  ..., 0.5798, 0.6406, 1.1936],
#            [0.4474, 0.9590, 0.5592,  ..., 0.7921, 0.7791, 0.6336],
#            [0.9450, 0.5910, 0.7239,  ..., 0.7865, 0.7471, 0.5572],
#            ...,
#            [0.5536, 0.6727, 1.0070,  ..., 0.6674, 1.2189, 0.7011],
#            [0.4842, 0.5871, 0.6954,  ..., 0.7043, 0.9860, 0.7895],
#            [0.7020, 0.7433, 0.8664,  ..., 0.5529, 0.7889, 0.8005]],
#
#           [[0.7196, 0.3207, 0.9218,  ..., 0.6925, 0.9509, 0.4740],
#            [0.9858, 1.0358, 0.5459,  ..., 0.9464, 0.4016, 0.5775],
#            [0.7281, 0.9938, 0.8871,  ..., 0.6001, 0.8402, 1.0374],
#            ...,
#            [0.8533, 1.0131, 0.5425,  ..., 0.8832, 0.4754, 0.7555],
#            [0.7653, 1.0432, 0.6744,  ..., 0.5842, 0.7185, 0.8080],
#            [0.4853, 0.7610, 0.5558,  ..., 0.8416, 0.6044, 0.9784]],
#
#           [[0.6224, 1.0267, 0.9031,  ..., 0.6286, 0.7636, 0.6316],
#            [0.9949, 0.5400, 0.3923,  ..., 0.7494, 0.4017, 0.5003],
#            [1.2642, 0.4963, 0.8992,  ..., 0.8460, 1.0868, 1.3053],
#            ...,
#            [0.6211, 0.5373, 0.8102,  ..., 0.8368, 0.7892, 1.0315],
#            [0.5378, 0.6785, 0.8107,  ..., 0.6532, 0.7171, 0.5774],
#            [0.8034, 0.6444, 0.9854,  ..., 0.5444, 0.5273, 0.7480]],
#
#           [[0.6030, 0.6670, 0.5706,  ..., 0.5578, 0.6974, 0.9863],
#            [0.8439, 0.4847, 0.7106,  ..., 0.5610, 0.7778, 0.4506],
#            [0.7859, 0.3478, 1.0372,  ..., 0.7525, 1.0591, 0.2940],
#            ...,
#            [0.6795, 0.5807, 0.8654,  ..., 0.8432, 0.8197, 0.6898],
#            [0.9770, 0.5094, 0.6678,  ..., 0.7466, 0.6382, 0.5085],
#            [0.5039, 0.6764, 0.6206,  ..., 0.7895, 1.3537, 0.8089]]]],
#         device='cuda:0')}

# %%
model, criterion, _, _, _ = training_setup()
tmp = next(iter(train_dataset))
outputs, aux_losses = model(process_inputs(tmp['inputs']).cuda())

aux_losses = sum(aux_losses)
(criterion(outputs, process_inputs(tmp['targets']).cuda()) + aux_losses).backward()
# Out:
# Original model 3464194 params, new model 3663874 params, ratio 1.06

# %%
list(model.blocks[-1].attention.lka.modules())[0][0].output_bias
# Out:
# Parameter containing:
# tensor([[[[-2.6187e-03, -5.7948e-04, -3.2907e-04,  6.2941e-04, -7.1119e-04,
#            -4.3961e-04,  2.6415e-03,  9.3061e-04,  2.9606e-03, -2.6636e-04,
#            -1.7387e-03,  1.6021e-03,  9.3624e-04,  1.1273e-03, -3.3982e-04,
#            -4.0739e-04, -2.0149e-03,  9.0991e-04, -1.0498e-03, -2.7959e-03,
#             2.5112e-04, -9.3633e-04,  6.2485e-04, -1.3612e-03, -2.9829e-04,
#            -2.0080e-04,  7.8189e-04,  7.8589e-04, -5.3443e-03, -3.7092e-03,
#            -2.3028e-04,  3.1588e-03, -2.2930e-04,  3.9736e-03,  4.0218e-04,
#             1.0651e-03,  7.7839e-03,  1.8654e-04, -3.1373e-03,  1.4372e-03,
#             4.1014e-03, -1.0334e-03, -8.9334e-04, -2.3530e-04, -1.0687e-03,
#            -2.1504e-03, -1.1092e-03,  1.7172e-05,  1.2050e-03, -1.5283e-03,
#             1.4103e-04, -2.1979e-03, -5.9292e-05,  2.5531e-03, -4.6291e-03,
#             8.9993e-04,  5.3557e-05, -1.8944e-03,  6.1842e-04, -3.0434e-03,
#            -2.6042e-03, -2.7910e-03,  1.9914e-03,  3.3585e-03]],
#
#          [[ 2.7830e-03,  6.5157e-04,  1.3587e-03,  2.6377e-03,  2.6050e-03,
#             1.3299e-04, -1.4192e-03,  4.3132e-04,  1.1622e-03,  1.8455e-03,
#            -6.5035e-03,  3.9105e-03,  3.6151e-03, -3.1340e-04, -1.1248e-03,
#            -9.3471e-03, -1.1168e-03, -1.2783e-03,  1.4718e-03, -1.7144e-03,
#            -1.5742e-03, -2.5472e-03, -3.9025e-04, -7.1958e-03,  2.0620e-03,
#             1.1221e-03,  4.0981e-03, -3.0099e-03, -2.8092e-03,  1.3933e-03,
#             1.2233e-03, -2.4611e-03, -7.4985e-03,  2.3598e-03,  1.5210e-04,
#             2.4839e-03, -1.8429e-03, -2.0700e-05,  2.3278e-03,  1.8919e-03,
#            -1.5871e-03, -5.1121e-03, -2.0640e-03, -5.9370e-03, -4.9204e-03,
#            -9.9108e-03, -1.5696e-03, -8.8422e-04, -2.8757e-03, -1.3572e-03,
#             3.9639e-04,  1.5128e-03, -8.5317e-04, -2.9370e-03, -1.1195e-03,
#             2.7233e-03, -4.3108e-03, -3.5303e-03,  2.7051e-03,  2.5042e-03,
#             7.5812e-04,  6.9706e-03, -1.0707e-03,  1.2404e-03]],
#
#          [[-3.8659e-03,  1.0261e-02,  2.7044e-03,  1.9696e-03, -1.4937e-04,
#            -5.3674e-03,  2.8987e-04,  5.6101e-04,  2.4013e-03,  1.1758e-03,
#            -3.7829e-03, -3.6720e-03,  5.8277e-04, -1.9636e-03,  3.7169e-03,
#             2.5876e-04, -5.9365e-03, -1.8047e-03,  3.1761e-03, -3.4872e-03,
#             2.8748e-03, -2.8431e-03,  6.1902e-03,  5.2007e-03,  6.6551e-03,
#             4.4296e-04,  3.4092e-04,  1.0645e-03,  8.4146e-03,  3.3517e-03,
#             4.8221e-03,  3.3170e-03, -3.9772e-05, -5.3822e-03, -1.1954e-03,
#            -2.6741e-05, -3.7010e-03,  4.8294e-03, -1.1520e-04, -1.9767e-04,
#            -6.4628e-03, -5.5500e-04,  3.8438e-03, -1.9857e-03,  3.4086e-03,
#             1.0389e-04,  3.8679e-03, -5.5254e-03, -1.2043e-03,  2.0952e-03,
#            -2.3705e-03,  5.6132e-03,  3.6401e-03, -5.2342e-03, -3.7908e-04,
#             1.2614e-03, -2.6454e-03, -4.1037e-03,  4.6147e-04,  3.8222e-03,
#             3.9316e-03,  1.1161e-03, -1.8010e-03, -9.9954e-03]],
#
#          [[ 8.1668e-04,  1.3635e-03,  4.4353e-04, -2.8064e-03,  2.3828e-04,
#             1.7759e-03,  2.0466e-04, -1.8902e-03,  2.3943e-04, -1.3520e-03,
#             2.3867e-03, -1.2658e-03, -1.5047e-03,  1.0777e-03, -4.2223e-03,
#             1.9186e-03, -2.0456e-03,  7.1799e-04,  5.4871e-04,  1.6659e-04,
#            -2.3044e-03, -3.2187e-03,  1.3099e-03, -1.5698e-03, -1.4281e-03,
#             2.3084e-03, -3.8172e-04, -1.0892e-03,  1.9725e-04, -1.0847e-03,
#             7.4281e-05, -9.6833e-04, -2.6583e-03, -1.4236e-03, -4.5038e-03,
#            -4.5519e-06, -1.1274e-03,  4.4086e-04,  8.0243e-05,  2.8444e-03,
#             1.6535e-03,  5.1128e-04,  1.4300e-03,  4.1248e-03, -3.1418e-03,
#            -4.7238e-03,  1.9891e-03,  2.6389e-03, -1.0230e-03, -1.4871e-03,
#             3.6018e-03,  1.1650e-03,  3.4906e-04,  1.1271e-04,  9.0374e-04,
#            -1.7273e-03,  3.5433e-05, -3.7748e-05, -1.9616e-03, -1.0358e-03,
#            -2.2366e-03, -3.8164e-04, -2.1304e-04,  7.8375e-04]]]],
#        device='cuda:0', requires_grad=True)
